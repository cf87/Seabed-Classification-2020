# %%
import numpy as np
import h5py
import scipy.io

# %%
# Loads KRAKEN data
def load_dataset(idx):
    filepath = "files_116/files_VLA_rand_"+ str(idx) +"_116.mat"
    
    mat = scipy.io.loadmat(filepath)
    signal_train=np.array([])
  
    # Training data
    args = (mat['p_cl_n'], mat['p_si_n'], mat['p_sa_n'],mat['p_gr_n'])
    for v in args: 
        tmp=np.vstack([np.real(v), np.imag(v)]) 
        signal_train=np.hstack([signal_train, tmp]) if signal_train.size else tmp
    
    
    labels_train=np.array([int(np.floor(i/1000)) for i in range(4000)])
    
    # Test data
    signal_test=np.array([])
    labels_test=[]
    
    for j in range(10):
        i=j+1
        args=(mat["p_cl_n"+str(i)], mat['p_si_n'+str(i)],
              mat["p_sa_n"+str(i)], mat["p_gr_n"+str(i)])
        for v in args: 
            tmp=np.vstack([np.real(v), np.imag(v)])
            signal_test=np.hstack([signal_test, tmp]) if signal_test.size else tmp

        labels_test=np.real(np.append([labels_test], [labels_train]))
    
    # Test labels are perturbed, associate them with the correct material type
    Y=labels_test
    labels=labels_test
    for i in range(len(labels)):
        if abs(labels[i]-1500)<20:
            Y[i]=0
        else:
            if abs(labels[i]-1575)<20:
                Y[i]=1
            else:
                if abs(labels[i]-1650)<20:
                    Y[i]=2
                else:
                    if abs(labels[i]-1800)<20:
                        Y[i]=3
    
    X_train = signal_train.transpose()
    y_train = np.array(labels_train, dtype=int);
    X_test = signal_test.transpose()
    y_test = np.array(Y, dtype=int);
    
    return X_train, y_train, X_test, y_test

# %%
from time import time
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# Benchmark metrics for each classifier
# Adapted from Peter Prettenhofer, et. al,
# https://scikit-learn.org/0.19/auto_examples/text/document_classification_20newsgroups.html
def benchmark(clf):
    print('_' * 80)
    print("Training: ")
   
    t0 = time()
    clf.fit(X_train, y_train)
 
    results=clf.cv_results_
    candidates = np.flatnonzero(results['rank_test_score'] == 1)
    for candidate in candidates:
        print("Model with rank: {0}".format(1))
        print("Mean validation score: {0:.3f} (std: {1:.3f})"
              .format(results['mean_test_score'][candidate],
                      results['std_test_score'][candidate]))
        print("Parameters: {0}".format(results['params'][candidate]))
        print("\n")

    target_names=[]
    targets=np.unique(y_train);

    for i in range(len(targets)):
        target_names.append(np.str(targets[i]))
    
    train_time = time() - t0
    print("train time: %0.3fs" % train_time)

    t0 = time()
    pred = clf.predict(X_test)
    test_time = time() - t0
    
    print("test time:  %0.3fs" % test_time)
    
    score = metrics.accuracy_score(y_test, pred)
    print("accuracy:   %0.3f" % score)
    print("classification report:")
    print(metrics.classification_report(y_test, pred, target_names=target_names))
    
    print("confusion matrix:")
    print(metrics.confusion_matrix(y_test, pred))

    clf_descr = str(str(clf.estimator))
    clf_rep = str(metrics.classification_report(y_test, pred, target_names=target_names))
    clf_cm = str(metrics.confusion_matrix(y_test, pred))
    return clf_descr, score, train_time, test_time, clf_rep, clf_cm

# %%
from scipy.stats import randint as sp_randint
from scipy.stats import uniform, expon
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier, NearestCentroid
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis


# list of (estimator, param_dist), where param_dist is used  in RandomizedSearchCV
classifiers = [
     (GaussianProcessClassifier(warm_start=True, n_jobs=-1, random_state=42),{
        'max_iter_predict': [10, 20, 50, 100, 200],
        'multi_class': ["one_vs_rest", "one_vs_one"],
        'n_restarts_optimizer':[0, 1]
     }),
     (KNeighborsClassifier(), {
         'n_neighbors': sp_randint(4, 10),
         'weights': ['uniform', 'distance'],
         'algorithm':['ball_tree', 'kd_tree'],
         'p': [1,2]
     }),
    (NearestCentroid(), {
         'metric': ['euclidean', 'manhattan','minkowski','chebyshev'],
         'shrink_threshold': [None, .001, .0001, .1, .01]
     }),
    (SVC(kernel='linear'), {
        'C': np.logspace(-1, 3, 100),
        'tol': np.logspace(-8, -2, 100)
    }),
    (SVC(random_state=42, gamma='scale'), {
        'C': [.1, 1, 10, 100, 1000],
        'kernel': ['rbf', 'poly', 'linear', 'sigmoid'], 
        'class_weight':['balanced', None],
        'tol': np.logspace(-8, -2, 100)
    }),
    (MLPClassifier(max_iter=100000), {
        'hidden_layer_sizes': [(50,50,50), (50,100,50), (100,)],
        'alpha': expon(scale=.1),
        'learning_rate': ['constant','adaptive'],
    }),
    (DecisionTreeClassifier(),{
        'criterion': ['gini', 'entropy'],
        'splitter': ['best','random'],
        'max_features':[None, 'auto', 'sqrt', 'log2'],
    }),
    (RandomForestClassifier(max_depth=5, n_jobs=-1), {
        "max_depth": sp_randint(2, 20),
        "n_estimators": sp_randint(2, 50),
        "max_features": ['auto', 'log2'],
        'class_weight': ['balanced', 'balanced_subsample'],
        'criterion': ['gini', 'entropy']
    }),
     (GaussianNB(), {
         'var_smoothing': np.logspace(-12, -8, 100)
     }), 
     (LinearDiscriminantAnalysis(n_components=2), {
         'solver': ['svd', 'lsqr'],
         'tol': np.logspace(-10, -2, 100)
     }),
     (LogisticRegression(solver='newton-cg', random_state=0, max_iter=100000), {
        'C': [.1, 1, 10, 100, 1000],
         'multi_class': ["auto", "ovr","multinomial"],
         'solver': ['sag', 'saga', 'newton-cg'],
         'tol': np.logspace(-6, -4, 100)
     }),
]
names = [e.__class__.__name__ for e, g in classifiers]

# %%
from sklearn.model_selection import RandomizedSearchCV
clf = RandomizedSearchCV(estimator=LinearDiscriminantAnalysis(n_components=2), param_distributions={'solver': ['svd', 'lsqr']}, n_iter=20, cv=5,
                                 verbose=0, n_jobs=-1)
X_train, y_train, X_test, y_test= load_dataset(15)
benchmark(clf)
# Out:
# ________________________________________________________________________________
# Training:
# /usr/local/lib/python3.7/site-packages/sklearn/model_selection/_search.py:266: UserWarning: The total space of parameters 2 is smaller than n_iter=20. Running 2 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'solver': 'lsqr'}
#
#
# train time: 0.286s
# test time:  0.003s
# accuracy:   0.809
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.25      0.40     10000
#            1       0.57      0.99      0.72     10000
#            2       0.99      0.99      0.99     10000
#            3       1.00      1.00      1.00     10000
#
#     accuracy                           0.81     40000
#    macro avg       0.89      0.81      0.78     40000
# weighted avg       0.89      0.81      0.78     40000
#
# confusion matrix:
# [[ 2517  7457    25     1]
#  [   13  9918    69     0]
#  [    0    63  9937     0]
#  [    0     0     0 10000]]
# ("LinearDiscriminantAnalysis(n_components=2, priors=None, shrinkage=None,\n                           solver='svd', store_covariance=False, tol=0.0001)",
#  0.8093,
#  0.28588080406188965,
#  0.003426074981689453,
#  '              precision    recall  f1-score   support\n\n           0       0.99      0.25      0.40     10000\n           1       0.57      0.99      0.72     10000\n           2       0.99      0.99      0.99     10000\n           3       1.00      1.00      1.00     10000\n\n    accuracy                           0.81     40000\n   macro avg       0.89      0.81      0.78     40000\nweighted avg       0.89      0.81      0.78     40000\n',
#  '[[ 2517  7457    25     1]\n [   13  9918    69     0]\n [    0    63  9937     0]\n [    0     0     0 10000]]')

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.utils.testing import ignore_warnings
from sklearn.exceptions import ConvergenceWarning
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import train_test_split


data_name=['KRAKEN 2 layer']
dset_name=data_name

noiselevel = np.array([15, 17 ,19, 21, 26, 30, 32 ,33, 60])
grid_searches = [dict() for x in range(len(noiselevel))]
results = [[] for x in range(len(noiselevel))]
ds_cnt=-1
for nl in noiselevel:
    ds_cnt=ds_cnt+1
    X_train, y_train, X_test, y_test= load_dataset(nl)
    
    print('\n Noise level:', str(nl),'\n')
   
    # iterate over classifiers
    for est_idx, (name, (estimator, param_grid)) in \
        enumerate(zip(names, classifiers)):

        # Perform randomized grid search over possible hyperparameters
        clf = RandomizedSearchCV(estimator=estimator, param_distributions=param_grid, n_iter=20, cv=5,
                                 verbose=0, n_jobs=-1)
        
        with ignore_warnings(category=ConvergenceWarning):
            results[ds_cnt].append(benchmark(clf))
        grid_searches[ds_cnt][name] = clf

        # Make predictions for the four test cases
        print(name)
        
        #print('Test Score', str(clf.score(X_test, y_test)))
# Out:
#  Noise level: 15
#
# ________________________________________________________________________________
# Training:
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'n_restarts_optimizer': 0, 'multi_class': 'one_vs_one', 'max_iter_predict': 10}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'n_restarts_optimizer': 1, 'multi_class': 'one_vs_one', 'max_iter_predict': 10}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'n_restarts_optimizer': 0, 'multi_class': 'one_vs_one', 'max_iter_predict': 20}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'n_restarts_optimizer': 1, 'multi_class': 'one_vs_one', 'max_iter_predict': 20}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'n_restarts_optimizer': 0, 'multi_class': 'one_vs_one', 'max_iter_predict': 50}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'n_restarts_optimizer': 1, 'multi_class': 'one_vs_one', 'max_iter_predict': 50}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'n_restarts_optimizer': 0, 'multi_class': 'one_vs_one', 'max_iter_predict': 100}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'n_restarts_optimizer': 1, 'multi_class': 'one_vs_one', 'max_iter_predict': 100}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'n_restarts_optimizer': 0, 'multi_class': 'one_vs_one', 'max_iter_predict': 200}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'n_restarts_optimizer': 1, 'multi_class': 'one_vs_one', 'max_iter_predict': 200}
#
#
# train time: 130.097s
# test time:  73.824s
# accuracy:   0.811
# classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.26      0.41     10000
#            1       0.57      0.99      0.72     10000
#            2       0.99      0.99      0.99     10000
#            3       1.00      1.00      1.00     10000
#
#     accuracy                           0.81     40000
#    macro avg       0.89      0.81      0.78     40000
# weighted avg       0.89      0.81      0.78     40000
#
# confusion matrix:
# [[ 2562  7406    31     1]
#  [   11  9935    54     0]
#  [    0    71  9929     0]
#  [    0     0     0 10000]]
# GaussianProcessClassifier
# ________________________________________________________________________________
# Training:
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'algorithm': 'ball_tree', 'n_neighbors': 9, 'p': 2, 'weights': 'distance'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'algorithm': 'kd_tree', 'n_neighbors': 9, 'p': 2, 'weights': 'distance'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'algorithm': 'ball_tree', 'n_neighbors': 9, 'p': 2, 'weights': 'uniform'}
#
#
# train time: 0.923s
# test time:  5.834s
# accuracy:   0.816
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.28      0.44     10000
#            1       0.58      0.99      0.73     10000
#            2       0.99      0.99      0.99     10000
#            3       1.00      1.00      1.00     10000
#
#     accuracy                           0.82     40000
#    macro avg       0.89      0.82      0.79     40000
# weighted avg       0.89      0.82      0.79     40000
#
# confusion matrix:
# [[ 2811  7143    45     1]
#  [   19  9910    71     0]
#  [    0    73  9927     0]
#  [    0     0     0 10000]]
# KNeighborsClassifier
# ________________________________________________________________________________
# Training:
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'shrink_threshold': None, 'metric': 'euclidean'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'shrink_threshold': 0.001, 'metric': 'euclidean'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'shrink_threshold': 0.0001, 'metric': 'euclidean'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'shrink_threshold': 0.1, 'metric': 'euclidean'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'shrink_threshold': 0.01, 'metric': 'euclidean'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'shrink_threshold': None, 'metric': 'minkowski'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'shrink_threshold': 0.001, 'metric': 'minkowski'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'shrink_threshold': 0.0001, 'metric': 'minkowski'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'shrink_threshold': 0.1, 'metric': 'minkowski'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'shrink_threshold': 0.01, 'metric': 'minkowski'}
#
#
# train time: 0.179s
# test time:  0.005s
# accuracy:   0.811
# classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.26      0.41     10000
#            1       0.57      0.99      0.72     10000
#            2       0.99      0.99      0.99     10000
#            3       1.00      1.00      1.00     10000
#
#     accuracy                           0.81     40000
#    macro avg       0.89      0.81      0.78     40000
# weighted avg       0.89      0.81      0.78     40000
#
# confusion matrix:
# [[ 2562  7406    31     1]
#  [   11  9935    54     0]
#  [    0    71  9929     0]
#  [    0     0     0 10000]]
# NearestCentroid
# ________________________________________________________________________________
# Training:
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 0.002477076355991714, 'C': 7.924828983539178}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 1.629750834620647e-05, 'C': 81.11308307896873}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 0.0032745491628777316, 'C': 475.0810162102798}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 1.1497569953977357e-08, 'C': 5.994842503189412}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 1.519911082952933e-06, 'C': 9.545484566618342}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 5.336699231206313e-06, 'C': 327.4549162877732}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 5.336699231206313e-06, 'C': 1.484968262254465}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 2.009233002565046e-08, 'C': 50.9413801481638}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 5.722367659350221e-07, 'C': 0.1}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 3.274549162877732e-05, 'C': 9.545484566618342}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 1.1497569953977357e-06, 'C': 225.70197196339214}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 8.111308307896873e-08, 'C': 141.7474162926806}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 0.01, 'C': 0.17475284000076838}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 0.002477076355991714, 'C': 0.40370172585965547}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 0.00011497569953977356, 'C': 0.9326033468832199}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 3.053855508833412e-08, 'C': 1.2328467394420666}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 5.3366992312063125e-08, 'C': 0.19179102616724888}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 1.2328467394420658e-05, 'C': 129.1549665014884}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 1.629750834620647e-05, 'C': 3.4304692863149193}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 0.008697490026177835, 'C': 117.68119524349991}
#
#
# train time: 3.874s
# test time:  4.830s
# accuracy:   0.817
# classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.28      0.44     10000
#            1       0.58      0.99      0.73     10000
#            2       0.99      0.99      0.99     10000
#            3       1.00      1.00      1.00     10000
#
#     accuracy                           0.82     40000
#    macro avg       0.89      0.82      0.79     40000
# weighted avg       0.89      0.82      0.79     40000
#
# confusion matrix:
# [[ 2817  7160    22     1]
#  [   14  9945    41     0]
#  [    0    90  9910     0]
#  [    0     0     0 10000]]
# SVC
# ________________________________________________________________________________
# Training:
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 1.8738174228603867e-05, 'kernel': 'rbf', 'class_weight': 'balanced', 'C': 0.1}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 6.579332246575682e-07, 'kernel': 'rbf', 'class_weight': 'balanced', 'C': 1}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 0.0037649358067924714, 'kernel': 'rbf', 'class_weight': None, 'C': 0.1}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 2.477076355991714e-05, 'kernel': 'rbf', 'class_weight': None, 'C': 0.1}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 8.111308307896873e-06, 'kernel': 'rbf', 'class_weight': None, 'C': 1}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 0.0002310129700083158, 'kernel': 'linear', 'class_weight': 'balanced', 'C': 1000}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 3.274549162877732e-05, 'kernel': 'rbf', 'class_weight': 'balanced', 'C': 1}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 3.764935806792471e-07, 'kernel': 'rbf', 'class_weight': None, 'C': 0.1}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 0.00011497569953977356, 'kernel': 'linear', 'class_weight': 'balanced', 'C': 1000}
#
#
# train time: 1.703s
# test time:  1.586s
# accuracy:   0.817
# classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.28      0.44     10000
#            1       0.58      0.99      0.73     10000
#            2       0.99      0.99      0.99     10000
#            3       1.00      1.00      1.00     10000
#
#     accuracy                           0.82     40000
#    macro avg       0.89      0.82      0.79     40000
# weighted avg       0.89      0.82      0.79     40000
#
# confusion matrix:
# [[ 2830  7145    24     1]
#  [   13  9928    59     0]
#  [    0    66  9934     0]
#  [    0     0     0 10000]]
# SVC
# ________________________________________________________________________________
# Training:
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'alpha': 0.004526683874604191, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant'}
#
#
# train time: 381.460s
# test time:  0.198s
# accuracy:   0.829
# classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.33      0.50     10000
#            1       0.60      0.99      0.74     10000
#            2       0.99      0.99      0.99     10000
#            3       1.00      1.00      1.00     10000
#
#     accuracy                           0.83     40000
#    macro avg       0.90      0.83      0.81     40000
# weighted avg       0.90      0.83      0.81     40000
#
# confusion matrix:
# [[ 3308  6665    23     4]
#  [   15  9945    40     0]
#  [    0    90  9910     0]
#  [    0     0     0 10000]]
# MLPClassifier
# ________________________________________________________________________________
# Training:
# /usr/local/lib/python3.7/site-packages/sklearn/model_selection/_search.py:266: UserWarning: The total space of parameters 16 is smaller than n_iter=20. Running 16 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# Model with rank: 1
# Mean validation score: 0.947 (std: 0.008)
# Parameters: {'splitter': 'best', 'max_features': None, 'criterion': 'entropy'}
#
#
# train time: 0.316s
# test time:  0.006s
# accuracy:   0.765
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.24      0.37     10000
#            1       0.53      0.90      0.67     10000
#            2       0.89      0.93      0.91     10000
#            3       0.99      0.99      0.99     10000
#
#     accuracy                           0.77     40000
#    macro avg       0.83      0.77      0.74     40000
# weighted avg       0.83      0.77      0.74     40000
#
# confusion matrix:
# [[2352 7158  435   55]
#  [ 274 8999  725    2]
#  [   1  655 9336    8]
#  [   0   68   12 9920]]
# DecisionTreeClassifier
# ________________________________________________________________________________
# Training:
# Model with rank: 1
# Mean validation score: 0.991 (std: 0.004)
# Parameters: {'class_weight': 'balanced', 'criterion': 'gini', 'max_depth': 19, 'max_features': 'log2', 'n_estimators': 49}
#
#
# train time: 8.067s
# test time:  0.112s
# accuracy:   0.814
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.29      0.45     10000
#            1       0.58      0.98      0.73     10000
#            2       0.98      0.98      0.98     10000
#            3       1.00      1.00      1.00     10000
#
#     accuracy                           0.81     40000
#    macro avg       0.88      0.81      0.79     40000
# weighted avg       0.88      0.81      0.79     40000
#
# confusion matrix:
# [[2931 6955  102   12]
#  [  83 9808  109    0]
#  [   0  187 9813    0]
#  [   0    1    0 9999]]
# RandomForestClassifier
# ________________________________________________________________________________
# Training:
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'var_smoothing': 4.132012400115335e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'var_smoothing': 3.0538555088334124e-12}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'var_smoothing': 1.3530477745798076e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'var_smoothing': 5.094138014816385e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'var_smoothing': 1.176811952434999e-09}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'var_smoothing': 1.2915496650148826e-09}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'var_smoothing': 1.7073526474706886e-09}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'var_smoothing': 5.72236765935022e-09}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'var_smoothing': 3.125715849688235e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'var_smoothing': 5.590810182512223e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'var_smoothing': 9.32603346883218e-12}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'var_smoothing': 6.734150657750828e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'var_smoothing': 1.5922827933410938e-12}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'var_smoothing': 5.214008287999695e-09}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'var_smoothing': 2.310129700083158e-12}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'var_smoothing': 2.5950242113997427e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'var_smoothing': 1.0974987654930545e-12}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'var_smoothing': 1.8307382802953697e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'var_smoothing': 5.462277217684337e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'var_smoothing': 2.1049041445120218e-12}
#
#
# train time: 0.166s
# test time:  0.034s
# accuracy:   0.811
# classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.26      0.41     10000
#            1       0.57      0.99      0.73     10000
#            2       0.99      0.99      0.99     10000
#            3       1.00      1.00      1.00     10000
#
#     accuracy                           0.81     40000
#    macro avg       0.89      0.81      0.78     40000
# weighted avg       0.89      0.81      0.78     40000
#
# confusion matrix:
# [[ 2567  7407    25     1]
#  [   11  9938    51     0]
#  [    0    70  9930     0]
#  [    0     0     0 10000]]
# GaussianNB
# ________________________________________________________________________________
# Training:
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 1.6297508346206469e-09, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 1.747528400007683e-10, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 0.000739072203352579, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 1.6297508346206469e-09, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 1.3530477745798075e-09, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 1.2328467394420684e-05, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 5.214008287999695e-07, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 2.364489412645407e-09, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 1.917910261672489e-06, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 0.004750810162102803, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 2.310129700083163e-06, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 1.592282793341094e-06, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 3.430469286314926e-09, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 2.782559402207126e-06, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 4.641588833612782e-08, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 4.4306214575838866e-10, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 3.8535285937105354e-08, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 3.7649358067924715e-05, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 1.592282793341094e-06, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 7.742636826811277e-10, 'solver': 'svd'}
#
#
# train time: 0.350s
# test time:  0.002s
# accuracy:   0.809
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.25      0.40     10000
#            1       0.57      0.99      0.72     10000
#            2       0.99      0.99      0.99     10000
#            3       1.00      1.00      1.00     10000
#
#     accuracy                           0.81     40000
#    macro avg       0.89      0.81      0.78     40000
# weighted avg       0.89      0.81      0.78     40000
#
# confusion matrix:
# [[ 2517  7457    25     1]
#  [   13  9918    69     0]
#  [    0    63  9937     0]
#  [    0     0     0 10000]]
# LinearDiscriminantAnalysis
# ________________________________________________________________________________
# Training:
# Model with rank: 1
# Mean validation score: 0.993 (std: 0.003)
# Parameters: {'tol': 5.094138014816386e-06, 'solver': 'newton-cg', 'multi_class': 'auto', 'C': 1000}
#
#
# Model with rank: 1
# Mean validation score: 0.993 (std: 0.003)
# Parameters: {'tol': 1.4508287784959403e-06, 'solver': 'saga', 'multi_class': 'auto', 'C': 1000}
#
#
# train time: 14.740s
# test time:  0.002s
# accuracy:   0.869
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.51      0.67     10000
#            1       0.67      0.97      0.79     10000
#            2       0.96      1.00      0.98     10000
#            3       1.00      1.00      1.00     10000
#
#     accuracy                           0.87     40000
#    macro avg       0.90      0.87      0.86     40000
# weighted avg       0.90      0.87      0.86     40000
#
# confusion matrix:
# [[ 5075  4727   193     5]
#  [   83  9707   210     0]
#  [    0    22  9978     0]
#  [    0     0     0 10000]]
# LogisticRegression
#  Noise level: 17
#
# ________________________________________________________________________________
# Training:
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'n_restarts_optimizer': 0, 'multi_class': 'one_vs_one', 'max_iter_predict': 10}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'n_restarts_optimizer': 1, 'multi_class': 'one_vs_one', 'max_iter_predict': 10}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'n_restarts_optimizer': 0, 'multi_class': 'one_vs_one', 'max_iter_predict': 20}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'n_restarts_optimizer': 1, 'multi_class': 'one_vs_one', 'max_iter_predict': 20}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'n_restarts_optimizer': 0, 'multi_class': 'one_vs_one', 'max_iter_predict': 50}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'n_restarts_optimizer': 1, 'multi_class': 'one_vs_one', 'max_iter_predict': 50}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'n_restarts_optimizer': 0, 'multi_class': 'one_vs_one', 'max_iter_predict': 100}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'n_restarts_optimizer': 1, 'multi_class': 'one_vs_one', 'max_iter_predict': 100}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'n_restarts_optimizer': 0, 'multi_class': 'one_vs_one', 'max_iter_predict': 200}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'n_restarts_optimizer': 1, 'multi_class': 'one_vs_one', 'max_iter_predict': 200}
#
#
# train time: 132.385s
# test time:  72.076s
# accuracy:   0.812
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.27      0.43     10000
#            1       0.57      0.99      0.73     10000
#            2       0.98      0.99      0.99     10000
#            3       1.00      1.00      1.00     10000
#
#     accuracy                           0.81     40000
#    macro avg       0.89      0.81      0.78     40000
# weighted avg       0.89      0.81      0.78     40000
#
# confusion matrix:
# [[ 2717  7210    72     1]
#  [   32  9864   104     0]
#  [    0   114  9886     0]
#  [    0     0     0 10000]]
# GaussianProcessClassifier
# ________________________________________________________________________________
# Training:
# Model with rank: 1
# Mean validation score: 0.992 (std: 0.002)
# Parameters: {'algorithm': 'kd_tree', 'n_neighbors': 8, 'p': 2, 'weights': 'uniform'}
#
#
# train time: 0.879s
# test time:  9.789s
# accuracy:   0.827
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.34      0.51     10000
#            1       0.60      0.98      0.74     10000
#            2       0.98      0.98      0.98     10000
#            3       1.00      1.00      1.00     10000
#
#     accuracy                           0.83     40000
#    macro avg       0.89      0.83      0.81     40000
# weighted avg       0.89      0.83      0.81     40000
#
# confusion matrix:
# [[ 3431  6488    80     1]
#  [   83  9811   106     0]
#  [    0   167  9833     0]
#  [    0     0     0 10000]]
# KNeighborsClassifier
# ________________________________________________________________________________
# Training:
# Model with rank: 1
# Mean validation score: 0.996 (std: 0.002)
# Parameters: {'shrink_threshold': 0.1, 'metric': 'euclidean'}
#
#
# Model with rank: 1
# Mean validation score: 0.996 (std: 0.002)
# Parameters: {'shrink_threshold': 0.1, 'metric': 'minkowski'}
#
#
# train time: 0.167s
# test time:  0.004s
# accuracy:   0.812
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.27      0.43     10000
#            1       0.57      0.99      0.73     10000
#            2       0.98      0.99      0.99     10000
#            3       1.00      1.00      1.00     10000
#
#     accuracy                           0.81     40000
#    macro avg       0.89      0.81      0.78     40000
# weighted avg       0.89      0.81      0.78     40000
#
# confusion matrix:
# [[ 2728  7197    74     1]
#  [   33  9862   105     0]
#  [    0   112  9888     0]
#  [    0     0     0 10000]]
# NearestCentroid
# ________________________________________________________________________________
# Training:
# Model with rank: 1
# Mean validation score: 0.996 (std: 0.001)
# Parameters: {'tol': 3.2745491628777317e-07, 'C': 689.2612104349702}
#
#
# train time: 3.399s
# test time:  3.883s
# accuracy:   0.814
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.28      0.44     10000
#            1       0.58      0.99      0.73     10000
#            2       0.98      0.99      0.99     10000
#            3       1.00      1.00      1.00     10000
#
#     accuracy                           0.81     40000
#    macro avg       0.89      0.81      0.79     40000
# weighted avg       0.89      0.81      0.79     40000
#
# confusion matrix:
# [[ 2814  7122    63     1]
#  [   35  9869    96     0]
#  [    0   119  9881     0]
#  [    0     0     0 10000]]
# SVC
# ________________________________________________________________________________
# Training:
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'tol': 5.72236765935022e-05, 'kernel': 'linear', 'class_weight': 'balanced', 'C': 1000}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'tol': 1.747528400007683e-08, 'kernel': 'rbf', 'class_weight': 'balanced', 'C': 0.1}
#
#
# train time: 3.097s
# test time:  3.438s
# accuracy:   0.811
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.27      0.42     10000
#            1       0.57      0.99      0.72     10000
#            2       0.98      0.99      0.99     10000
#            3       1.00      1.00      1.00     10000
#
#     accuracy                           0.81     40000
#    macro avg       0.89      0.81      0.78     40000
# weighted avg       0.89      0.81      0.78     40000
#
# confusion matrix:
# [[ 2685  7245    69     1]
#  [   32  9861   107     0]
#  [    0   112  9888     0]
#  [    0     0     0 10000]]
# SVC
# ________________________________________________________________________________
# Training:
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'alpha': 0.001960208451440564, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive'}
#
#
# train time: 423.611s
# test time:  0.195s
# accuracy:   0.832
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.35      0.52     10000
#            1       0.60      0.99      0.75     10000
#            2       0.99      0.98      0.99     10000
#            3       1.00      1.00      1.00     10000
#
#     accuracy                           0.83     40000
#    macro avg       0.89      0.83      0.81     40000
# weighted avg       0.89      0.83      0.81     40000
#
# confusion matrix:
# [[ 3545  6415    35     5]
#  [   53  9887    60     0]
#  [    0   164  9836     0]
#  [    0     0     0 10000]]
# MLPClassifier
# ________________________________________________________________________________
# Training:
# /usr/local/lib/python3.7/site-packages/sklearn/model_selection/_search.py:266: UserWarning: The total space of parameters 16 is smaller than n_iter=20. Running 16 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# Model with rank: 1
# Mean validation score: 0.934 (std: 0.005)
# Parameters: {'splitter': 'best', 'max_features': None, 'criterion': 'entropy'}
#
#
# train time: 0.337s
# test time:  0.006s
# accuracy:   0.761
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.28      0.42     10000
#            1       0.56      0.86      0.68     10000
#            2       0.80      0.91      0.85     10000
#            3       0.99      0.99      0.99     10000
#
#     accuracy                           0.76     40000
#    macro avg       0.80      0.76      0.74     40000
# weighted avg       0.80      0.76      0.74     40000
#
# confusion matrix:
# [[2832 5801 1321   46]
#  [ 476 8648  831   45]
#  [  12  860 9082   46]
#  [  19   33   65 9883]]
# DecisionTreeClassifier
# ________________________________________________________________________________
# Training:
# Model with rank: 1
# Mean validation score: 0.982 (std: 0.003)
# Parameters: {'class_weight': 'balanced_subsample', 'criterion': 'entropy', 'max_depth': 14, 'max_features': 'auto', 'n_estimators': 45}
#
#
# Model with rank: 1
# Mean validation score: 0.982 (std: 0.005)
# Parameters: {'class_weight': 'balanced_subsample', 'criterion': 'gini', 'max_depth': 14, 'max_features': 'auto', 'n_estimators': 28}
#
#
# train time: 6.971s
# test time:  0.108s
# accuracy:   0.803
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.27      0.43     10000
#            1       0.57      0.96      0.71     10000
#            2       0.96      0.97      0.97     10000
#            3       1.00      1.00      1.00     10000
#
#     accuracy                           0.80     40000
#    macro avg       0.87      0.80      0.78     40000
# weighted avg       0.87      0.80      0.78     40000
#
# confusion matrix:
# [[2737 7107  147    9]
#  [ 128 9640  232    0]
#  [   0  252 9748    0]
#  [   0    5    0 9995]]
# RandomForestClassifier
# ________________________________________________________________________________
# Training:
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'var_smoothing': 1.0476157527896662e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'var_smoothing': 7.054802310718631e-12}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'var_smoothing': 7.390722033525775e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'var_smoothing': 2.656087782946684e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'var_smoothing': 1.3219411484660287e-12}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'var_smoothing': 1.2618568830660183e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'var_smoothing': 5.336699231206302e-12}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'var_smoothing': 6.428073117284319e-12}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'var_smoothing': 2.5950242113997427e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'var_smoothing': 1.4849682622544636e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'var_smoothing': 1.4174741629268078e-09}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'var_smoothing': 7.924828983539185e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'var_smoothing': 4.977023564332114e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'var_smoothing': 4.8626015800653536e-12}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'var_smoothing': 2.4770763559917138e-09}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'var_smoothing': 3.1992671377973845e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'var_smoothing': 1.1497569953977356e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'var_smoothing': 1.0722672220103253e-09}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'var_smoothing': 6.135907273413189e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'var_smoothing': 3.853528593710535e-10}
#
#
# train time: 0.187s
# test time:  0.034s
# accuracy:   0.811
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.27      0.42     10000
#            1       0.57      0.99      0.72     10000
#            2       0.98      0.99      0.99     10000
#            3       1.00      1.00      1.00     10000
#
#     accuracy                           0.81     40000
#    macro avg       0.89      0.81      0.78     40000
# weighted avg       0.89      0.81      0.78     40000
#
# confusion matrix:
# [[ 2693  7243    63     1]
#  [   34  9863   103     0]
#  [    0   116  9884     0]
#  [    0     0     0 10000]]
# GaussianNB
# ________________________________________________________________________________
# Training:
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'tol': 2.98364724028334e-07, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'tol': 3.430469286314926e-09, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'tol': 1.3530477745798075e-09, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'tol': 4.132012400115335e-09, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'tol': 0.0002915053062825182, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'tol': 1.747528400007683e-10, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'tol': 2.310129700083163e-06, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'tol': 0.0032745491628777316, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'tol': 2.1544346900318867e-05, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'tol': 9.545484566618347e-05, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'tol': 1.9630406500402685e-09, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'tol': 3.125715849688242e-05, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'tol': 2.104904144512022e-10, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'tol': 1.0974987654930568e-06, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'tol': 0.00689261210434971, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'tol': 1.2328467394420684e-05, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'tol': 0.0010722672220103253, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'tol': 0.008302175681319753, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'tol': 7.742636826811277e-10, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.002)
# Parameters: {'tol': 0.0006135907273413176, 'solver': 'lsqr'}
#
#
# train time: 0.284s
# test time:  0.005s
# accuracy:   0.810
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.27      0.42     10000
#            1       0.57      0.99      0.72     10000
#            2       0.98      0.99      0.99     10000
#            3       1.00      1.00      1.00     10000
#
#     accuracy                           0.81     40000
#    macro avg       0.89      0.81      0.78     40000
# weighted avg       0.89      0.81      0.78     40000
#
# confusion matrix:
# [[ 2656  7283    60     1]
#  [   33  9853   114     0]
#  [    0   102  9898     0]
#  [    0     0     0 10000]]
# LinearDiscriminantAnalysis
# ________________________________________________________________________________
# Training:
# Model with rank: 1
# Mean validation score: 0.987 (std: 0.003)
# Parameters: {'tol': 5.2140082879996844e-05, 'solver': 'newton-cg', 'multi_class': 'multinomial', 'C': 1000}
#
#
# Model with rank: 1
# Mean validation score: 0.987 (std: 0.003)
# Parameters: {'tol': 1.6681005372000591e-06, 'solver': 'newton-cg', 'multi_class': 'multinomial', 'C': 1000}
#
#
# train time: 10.183s
# test time:  0.002s
# accuracy:   0.861
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.50      0.66     10000
#            1       0.67      0.95      0.78     10000
#            2       0.94      1.00      0.97     10000
#            3       1.00      1.00      1.00     10000
#
#     accuracy                           0.86     40000
#    macro avg       0.89      0.86      0.85     40000
# weighted avg       0.89      0.86      0.85     40000
#
# confusion matrix:
# [[ 4970  4717   304     9]
#  [  168  9508   324     0]
#  [    0    44  9956     0]
#  [    0     0     0 10000]]
# LogisticRegression
#
#  Noise level: 19
#
# ________________________________________________________________________________
# Training:
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.002)
# Parameters: {'n_restarts_optimizer': 0, 'multi_class': 'one_vs_one', 'max_iter_predict': 10}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.002)
# Parameters: {'n_restarts_optimizer': 1, 'multi_class': 'one_vs_one', 'max_iter_predict': 10}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.002)
# Parameters: {'n_restarts_optimizer': 0, 'multi_class': 'one_vs_one', 'max_iter_predict': 20}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.002)
# Parameters: {'n_restarts_optimizer': 1, 'multi_class': 'one_vs_one', 'max_iter_predict': 20}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.002)
# Parameters: {'n_restarts_optimizer': 0, 'multi_class': 'one_vs_one', 'max_iter_predict': 50}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.002)
# Parameters: {'n_restarts_optimizer': 1, 'multi_class': 'one_vs_one', 'max_iter_predict': 50}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.002)
# Parameters: {'n_restarts_optimizer': 0, 'multi_class': 'one_vs_one', 'max_iter_predict': 100}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.002)
# Parameters: {'n_restarts_optimizer': 1, 'multi_class': 'one_vs_one', 'max_iter_predict': 100}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.002)
# Parameters: {'n_restarts_optimizer': 0, 'multi_class': 'one_vs_one', 'max_iter_predict': 200}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.002)
# Parameters: {'n_restarts_optimizer': 1, 'multi_class': 'one_vs_one', 'max_iter_predict': 200}
#
#
# train time: 132.345s
# test time:  72.920s
# accuracy:   0.811
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.28      0.44     10000
#            1       0.58      0.98      0.72     10000
#            2       0.97      0.98      0.98     10000
#            3       1.00      1.00      1.00     10000
#
#     accuracy                           0.81     40000
#    macro avg       0.88      0.81      0.79     40000
# weighted avg       0.88      0.81      0.79     40000
#
# confusion matrix:
# [[ 2841  7031   127     1]
#  [   72  9758   170     0]
#  [    0   160  9840     0]
#  [    0     0     0 10000]]
# GaussianProcessClassifier
# ________________________________________________________________________________
# Training:
# Model with rank: 1
# Mean validation score: 0.983 (std: 0.004)
# Parameters: {'algorithm': 'ball_tree', 'n_neighbors': 8, 'p': 2, 'weights': 'uniform'}
#
#
# train time: 0.979s
# test time:  7.056s
# accuracy:   0.825
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.36      0.53     10000
#            1       0.60      0.96      0.74     10000
#            2       0.97      0.97      0.97     10000
#            3       1.00      1.00      1.00     10000
#
#     accuracy                           0.83     40000
#    macro avg       0.88      0.83      0.81     40000
# weighted avg       0.88      0.83      0.81     40000
#
# confusion matrix:
# [[ 3627  6224   148     1]
#  [  179  9645   176     0]
#  [    0   266  9734     0]
#  [    0     0     0 10000]]
# KNeighborsClassifier
# ________________________________________________________________________________
# Training:
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.002)
# Parameters: {'shrink_threshold': None, 'metric': 'euclidean'}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.002)
# Parameters: {'shrink_threshold': 0.001, 'metric': 'euclidean'}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.002)
# Parameters: {'shrink_threshold': 0.0001, 'metric': 'euclidean'}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.002)
# Parameters: {'shrink_threshold': 0.01, 'metric': 'euclidean'}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.002)
# Parameters: {'shrink_threshold': None, 'metric': 'minkowski'}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.002)
# Parameters: {'shrink_threshold': 0.001, 'metric': 'minkowski'}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.002)
# Parameters: {'shrink_threshold': 0.0001, 'metric': 'minkowski'}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.002)
# Parameters: {'shrink_threshold': 0.01, 'metric': 'minkowski'}
#
#
# train time: 0.155s
# test time:  0.005s
# accuracy:   0.811
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.28      0.44     10000
#            1       0.58      0.98      0.72     10000
#            2       0.97      0.98      0.98     10000
#            3       1.00      1.00      1.00     10000
#
#     accuracy                           0.81     40000
#    macro avg       0.88      0.81      0.79     40000
# weighted avg       0.88      0.81      0.79     40000
#
# confusion matrix:
# [[ 2842  7030   127     1]
#  [   72  9758   170     0]
#  [    0   160  9840     0]
#  [    0     0     0 10000]]
# NearestCentroid
# ________________________________________________________________________________
# Training:
# Model with rank: 1
# Mean validation score: 0.989 (std: 0.003)
# Parameters: {'tol': 1.1497569953977357e-08, 'C': 830.2175681319752}
#
#
# train time: 3.308s
# test time:  3.707s
# accuracy:   0.809
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.28      0.43     10000
#            1       0.57      0.98      0.72     10000
#            2       0.97      0.98      0.98     10000
#            3       1.00      1.00      1.00     10000
#
#     accuracy                           0.81     40000
#    macro avg       0.88      0.81      0.78     40000
# weighted avg       0.88      0.81      0.78     40000
#
# confusion matrix:
# [[ 2766  7113   120     1]
#  [   70  9765   165     0]
#  [    0   171  9829     0]
#  [    0     0     0 10000]]
# SVC
# ________________________________________________________________________________
# Training:
# Model with rank: 1
# Mean validation score: 0.991 (std: 0.002)
# Parameters: {'tol': 0.01, 'kernel': 'sigmoid', 'class_weight': None, 'C': 0.1}
#
#
# train time: 3.119s
# test time:  1.973s
# accuracy:   0.815
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.30      0.46     10000
#            1       0.58      0.97      0.73     10000
#            2       0.97      0.99      0.98     10000
#            3       1.00      1.00      1.00     10000
#
#     accuracy                           0.81     40000
#    macro avg       0.88      0.81      0.79     40000
# weighted avg       0.88      0.81      0.79     40000
#
# confusion matrix:
# [[ 3002  6895    96     7]
#  [   69  9735   196     0]
#  [    0   146  9854     0]
#  [    0     0     0 10000]]
# SVC
# ________________________________________________________________________________
# Training:
# Model with rank: 1
# Mean validation score: 0.991 (std: 0.002)
# Parameters: {'alpha': 0.0024007763459746416, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant'}
#
#
# train time: 408.191s
# test time:  0.195s
# accuracy:   0.818
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.31      0.47     10000
#            1       0.59      0.97      0.73     10000
#            2       0.97      0.99      0.98     10000
#            3       1.00      1.00      1.00     10000
#
#     accuracy                           0.82     40000
#    macro avg       0.88      0.82      0.80     40000
# weighted avg       0.88      0.82      0.80     40000
#
# confusion matrix:
# [[ 3135  6706   145    14]
#  [   68  9736   196     0]
#  [    0   142  9858     0]
#  [    0     0     0 10000]]
# MLPClassifier
# ________________________________________________________________________________
# Training:
# /usr/local/lib/python3.7/site-packages/sklearn/model_selection/_search.py:266: UserWarning: The total space of parameters 16 is smaller than n_iter=20. Running 16 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# Model with rank: 1
# Mean validation score: 0.897 (std: 0.010)
# Parameters: {'splitter': 'best', 'max_features': None, 'criterion': 'entropy'}
#
#
# train time: 0.343s
# test time:  0.007s
# accuracy:   0.764
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.38      0.53     10000
#            1       0.57      0.80      0.67     10000
#            2       0.79      0.89      0.84     10000
#            3       0.98      0.97      0.98     10000
#
#     accuracy                           0.76     40000
#    macro avg       0.79      0.76      0.75     40000
# weighted avg       0.79      0.76      0.75     40000
#
# confusion matrix:
# [[3845 4953 1113   89]
#  [ 704 8048 1199   49]
#  [  43  951 8940   66]
#  [   9  231   45 9715]]
# DecisionTreeClassifier
# ________________________________________________________________________________
# Training:
# Model with rank: 1
# Mean validation score: 0.973 (std: 0.004)
# Parameters: {'class_weight': 'balanced', 'criterion': 'gini', 'max_depth': 18, 'max_features': 'log2', 'n_estimators': 45}
#
#
# train time: 6.611s
# test time:  0.108s
# accuracy:   0.809
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.32      0.48     10000
#            1       0.58      0.95      0.72     10000
#            2       0.94      0.97      0.95     10000
#            3       1.00      1.00      1.00     10000
#
#     accuracy                           0.81     40000
#    macro avg       0.86      0.81      0.79     40000
# weighted avg       0.86      0.81      0.79     40000
#
# confusion matrix:
# [[3213 6492  283   12]
#  [ 221 9462  315    2]
#  [   3  309 9686    2]
#  [   0    3    1 9996]]
# RandomForestClassifier
# ...
#
#
# Model with rank: 1
# Mean validation score: 0.727 (std: 0.017)
# Parameters: {'n_restarts_optimizer': 1, 'multi_class': 'one_vs_one', 'max_iter_predict': 10}
#
#
# Model with rank: 1
# Mean validation score: 0.727 (std: 0.017)
# Parameters: {'n_restarts_optimizer': 0, 'multi_class': 'one_vs_one', 'max_iter_predict': 20}
#
#
# Model with rank: 1
# Mean validation score: 0.727 (std: 0.017)
# Parameters: {'n_restarts_optimizer': 1, 'multi_class': 'one_vs_one', 'max_iter_predict': 20}
#
#
# Model with rank: 1
# Mean validation score: 0.727 (std: 0.017)
# Parameters: {'n_restarts_optimizer': 0, 'multi_class': 'one_vs_one', 'max_iter_predict': 50}
#
#
# Model with rank: 1
# Mean validation score: 0.727 (std: 0.017)
# Parameters: {'n_restarts_optimizer': 1, 'multi_class': 'one_vs_one', 'max_iter_predict': 50}
#
#
# Model with rank: 1
# Mean validation score: 0.727 (std: 0.017)
# Parameters: {'n_restarts_optimizer': 0, 'multi_class': 'one_vs_one', 'max_iter_predict': 100}
#
#
# Model with rank: 1
# Mean validation score: 0.727 (std: 0.017)
# Parameters: {'n_restarts_optimizer': 1, 'multi_class': 'one_vs_one', 'max_iter_predict': 100}
#
#
# Model with rank: 1
# Mean validation score: 0.727 (std: 0.017)
# Parameters: {'n_restarts_optimizer': 0, 'multi_class': 'one_vs_one', 'max_iter_predict': 200}
#
#
# Model with rank: 1
# Mean validation score: 0.727 (std: 0.017)
# Parameters: {'n_restarts_optimizer': 1, 'multi_class': 'one_vs_one', 'max_iter_predict': 200}
#
#
# train time: 133.674s
# test time:  72.760s
# accuracy:   0.635
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.56      0.36      0.44     10000
#            1       0.48      0.56      0.52     10000
#            2       0.64      0.72      0.68     10000
#            3       0.84      0.90      0.87     10000
#
#     accuracy                           0.63     40000
#    macro avg       0.63      0.63      0.63     40000
# weighted avg       0.63      0.63      0.63     40000
#
# confusion matrix:
# [[3575 3862 1792  771]
#  [1978 5573 1978  471]
#  [ 624 1667 7249  460]
#  [ 225  430  356 8989]]
# GaussianProcessClassifier
# ________________________________________________________________________________
# Training:
# Model with rank: 1
# Mean validation score: 0.616 (std: 0.020)
# Parameters: {'algorithm': 'ball_tree', 'n_neighbors': 9, 'p': 2, 'weights': 'distance'}
#
#
# train time: 0.958s
# test time:  6.516s
# accuracy:   0.559
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.48      0.33      0.39     10000
#            1       0.41      0.48      0.44     10000
#            2       0.55      0.60      0.57     10000
#            3       0.79      0.83      0.81     10000
#
#     accuracy                           0.56     40000
#    macro avg       0.56      0.56      0.55     40000
# weighted avg       0.56      0.56      0.55     40000
#
# confusion matrix:
# [[3276 3800 1952  972]
#  [2287 4797 2310  606]
#  [ 938 2417 5959  686]
#  [ 337  774  573 8316]]
# KNeighborsClassifier
# ________________________________________________________________________________
# Training:
# Model with rank: 1
# Mean validation score: 0.727 (std: 0.017)
# Parameters: {'shrink_threshold': 0.01, 'metric': 'euclidean'}
#
#
# Model with rank: 1
# Mean validation score: 0.727 (std: 0.017)
# Parameters: {'shrink_threshold': 0.01, 'metric': 'minkowski'}
#
#
# train time: 0.162s
# test time:  0.005s
# accuracy:   0.635
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.56      0.36      0.44     10000
#            1       0.48      0.56      0.52     10000
#            2       0.64      0.73      0.68     10000
#            3       0.84      0.90      0.87     10000
#
#     accuracy                           0.63     40000
#    macro avg       0.63      0.63      0.63     40000
# weighted avg       0.63      0.63      0.63     40000
#
# confusion matrix:
# [[3576 3862 1792  770]
#  [1982 5566 1981  471]
#  [ 623 1662 7255  460]
#  [ 226  429  356 8989]]
# NearestCentroid
# ________________________________________________________________________________
# Training:
# Model with rank: 1
# Mean validation score: 0.729 (std: 0.016)
# Parameters: {'tol': 1.417474162926805e-07, 'C': 271.85882427329426}
#
#
# train time: 3.425s
# test time:  4.431s
# accuracy:   0.635
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.56      0.37      0.44     10000
#            1       0.48      0.55      0.51     10000
#            2       0.64      0.72      0.68     10000
#            3       0.84      0.90      0.87     10000
#
#     accuracy                           0.63     40000
#    macro avg       0.63      0.63      0.63     40000
# weighted avg       0.63      0.63      0.63     40000
#
# confusion matrix:
# [[3655 3838 1765  742]
#  [2047 5515 1981  457]
#  [ 643 1652 7250  455]
#  [ 240  434  364 8962]]
# SVC
# ________________________________________________________________________________
# Training:
# Model with rank: 1
# Mean validation score: 0.726 (std: 0.017)
# Parameters: {'tol': 7.0548023107186455e-06, 'kernel': 'linear', 'class_weight': None, 'C': 100}
#
#
# Model with rank: 1
# Mean validation score: 0.726 (std: 0.017)
# Parameters: {'tol': 0.0002310129700083158, 'kernel': 'linear', 'class_weight': None, 'C': 100}
#
#
# train time: 3.940s
# test time:  4.594s
# accuracy:   0.636
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.54      0.41      0.47     10000
#            1       0.49      0.52      0.50     10000
#            2       0.64      0.71      0.68     10000
#            3       0.84      0.90      0.87     10000
#
#     accuracy                           0.64     40000
#    macro avg       0.63      0.64      0.63     40000
# weighted avg       0.63      0.64      0.63     40000
#
# confusion matrix:
# [[4077 3466 1694  763]
#  [2401 5223 1903  473]
#  [ 756 1626 7147  471]
#  [ 266  399  339 8996]]
# SVC
# ________________________________________________________________________________
# Training:
# Model with rank: 1
# Mean validation score: 0.691 (std: 0.015)
# Parameters: {'alpha': 0.021769708589617937, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant'}
#
#
# train time: 321.782s
# test time:  0.038s
# accuracy:   0.602
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.53      0.38      0.44     10000
#            1       0.43      0.31      0.36     10000
#            2       0.56      0.81      0.66     10000
#            3       0.81      0.92      0.86     10000
#
#     accuracy                           0.60     40000
#    macro avg       0.58      0.60      0.58     40000
# weighted avg       0.58      0.60      0.58     40000
#
# confusion matrix:
# [[3786 2769 2474  971]
#  [2836 3070 3430  664]
#  [ 379 1060 8066  495]
#  [ 182  220  446 9152]]
# MLPClassifier
# ________________________________________________________________________________
# Training:
# /usr/local/lib/python3.7/site-packages/sklearn/model_selection/_search.py:266: UserWarning: The total space of parameters 16 is smaller than n_iter=20. Running 16 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# Model with rank: 1
# Mean validation score: 0.488 (std: 0.021)
# Parameters: {'splitter': 'best', 'max_features': None, 'criterion': 'entropy'}
#
#
# train time: 0.503s
# test time:  0.008s
# accuracy:   0.448
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.39      0.32      0.35     10000
#            1       0.33      0.34      0.33     10000
#            2       0.43      0.46      0.45     10000
#            3       0.63      0.67      0.65     10000
#
#     accuracy                           0.45     40000
#    macro avg       0.44      0.45      0.45     40000
# weighted avg       0.44      0.45      0.45     40000
#
# confusion matrix:
# [[3222 3086 2254 1438]
#  [2666 3391 2722 1221]
#  [1579 2488 4641 1292]
#  [ 894 1309 1124 6673]]
# DecisionTreeClassifier
# ________________________________________________________________________________
# Training:
# Model with rank: 1
# Mean validation score: 0.642 (std: 0.007)
# Parameters: {'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 17, 'max_features': 'auto', 'n_estimators': 44}
#
#
# train time: 8.512s
# test time:  0.110s
# accuracy:   0.572
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.49      0.38      0.43     10000
#            1       0.43      0.42      0.42     10000
#            2       0.58      0.64      0.61     10000
#            3       0.75      0.85      0.79     10000
#
#     accuracy                           0.57     40000
#    macro avg       0.56      0.57      0.56     40000
# weighted avg       0.56      0.57      0.56     40000
#
# confusion matrix:
# [[3832 3267 1758 1143]
#  [2585 4187 2341  887]
#  [ 985 1761 6383  871]
#  [ 382  595  530 8493]]
# RandomForestClassifier
# ________________________________________________________________________________
# Training:
# Model with rank: 1
# Mean validation score: 0.723 (std: 0.012)
# Parameters: {'var_smoothing': 2.1049041445120218e-12}
#
#
# Model with rank: 1
# Mean validation score: 0.723 (std: 0.012)
# Parameters: {'var_smoothing': 3.351602650938848e-12}
#
#
# Model with rank: 1
# Mean validation score: 0.723 (std: 0.012)
# Parameters: {'var_smoothing': 1.5199110829529332e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.723 (std: 0.012)
# Parameters: {'var_smoothing': 2.5950242113997427e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.723 (std: 0.012)
# Parameters: {'var_smoothing': 2.71858824273294e-09}
#
#
# Model with rank: 1
# Mean validation score: 0.723 (std: 0.012)
# Parameters: {'var_smoothing': 1.2618568830660183e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.723 (std: 0.012)
# Parameters: {'var_smoothing': 2.0092330025650458e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.723 (std: 0.012)
# Parameters: {'var_smoothing': 1.1497569953977356e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.723 (std: 0.012)
# Parameters: {'var_smoothing': 4.229242874389499e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.723 (std: 0.012)
# Parameters: {'var_smoothing': 5.336699231206302e-12}
#
#
# Model with rank: 1
# Mean validation score: 0.723 (std: 0.012)
# Parameters: {'var_smoothing': 1.0974987654930545e-12}
#
#
# Model with rank: 1
# Mean validation score: 0.723 (std: 0.012)
# Parameters: {'var_smoothing': 9.32603346883218e-12}
#
#
# Model with rank: 1
# Mean validation score: 0.723 (std: 0.012)
# Parameters: {'var_smoothing': 2.205130739903041e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.723 (std: 0.012)
# Parameters: {'var_smoothing': 4.7508101621027936e-09}
#
#
# Model with rank: 1
# Mean validation score: 0.723 (std: 0.012)
# Parameters: {'var_smoothing': 5.857020818056673e-12}
#
#
# Model with rank: 1
# Mean validation score: 0.723 (std: 0.012)
# Parameters: {'var_smoothing': 1.0235310218990269e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.723 (std: 0.012)
# Parameters: {'var_smoothing': 1.6681005372000558e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.723 (std: 0.012)
# Parameters: {'var_smoothing': 7.054802310718631e-12}
#
#
# Model with rank: 1
# Mean validation score: 0.723 (std: 0.012)
# Parameters: {'var_smoothing': 1.5556761439304723e-09}
#
#
# Model with rank: 1
# Mean validation score: 0.723 (std: 0.012)
# Parameters: {'var_smoothing': 4.132012400115335e-11}
#
#
# train time: 0.159s
# test time:  0.033s
# accuracy:   0.633
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.56      0.36      0.44     10000
#            1       0.48      0.55      0.51     10000
#            2       0.63      0.72      0.68     10000
#            3       0.84      0.90      0.87     10000
#
#     accuracy                           0.63     40000
#    macro avg       0.63      0.63      0.62     40000
# weighted avg       0.63      0.63      0.62     40000
#
# confusion matrix:
# [[3622 3822 1790  766]
#  [2011 5497 2025  467]
#  [ 632 1673 7223  472]
#  [ 237  425  348 8990]]
# GaussianNB
# ________________________________________________________________________________
# Training:
# Model with rank: 1
# Mean validation score: 0.725 (std: 0.016)
# Parameters: {'tol': 0.0005094138014816386, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.725 (std: 0.016)
# Parameters: {'tol': 5.5908101825122226e-08, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.725 (std: 0.016)
# Parameters: {'tol': 0.0032745491628777316, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.725 (std: 0.016)
# Parameters: {'tol': 1.917910261672489e-06, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.725 (std: 0.016)
# Parameters: {'tol': 6.579332246575683e-05, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.725 (std: 0.016)
# Parameters: {'tol': 2.310129700083163e-06, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.725 (std: 0.016)
# Parameters: {'tol': 0.000200923300256505, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.725 (std: 0.016)
# Parameters: {'tol': 4.862601580065354e-06, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.725 (std: 0.016)
# Parameters: {'tol': 0.008302175681319753, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.725 (std: 0.016)
# Parameters: {'tol': 5.5908101825122226e-08, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.725 (std: 0.016)
# Parameters: {'tol': 2.0565123083486514e-07, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.725 (std: 0.016)
# Parameters: {'tol': 1.1768119524349991e-07, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.725 (std: 0.016)
# Parameters: {'tol': 1.788649529057435e-05, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.725 (std: 0.016)
# Parameters: {'tol': 0.00024201282647943835, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.725 (std: 0.016)
# Parameters: {'tol': 1.1768119524349991e-07, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.725 (std: 0.016)
# Parameters: {'tol': 1.6297508346206469e-09, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.725 (std: 0.016)
# Parameters: {'tol': 0.0018738174228603867, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.725 (std: 0.016)
# Parameters: {'tol': 7.564633275546291e-07, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.725 (std: 0.016)
# Parameters: {'tol': 0.0022570197196339213, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.725 (std: 0.016)
# Parameters: {'tol': 7.564633275546291e-07, 'solver': 'lsqr'}
#
#
# train time: 0.331s
# test time:  0.003s
# accuracy:   0.633
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.56      0.36      0.44     10000
#            1       0.48      0.55      0.51     10000
#            2       0.63      0.73      0.68     10000
#            3       0.84      0.90      0.87     10000
#
#     accuracy                           0.63     40000
#    macro avg       0.63      0.63      0.62     40000
# weighted avg       0.63      0.63      0.62     40000
#
# confusion matrix:
# [[3595 3852 1785  768]
#  [1988 5489 2059  464]
#  [ 621 1644 7275  460]
#  [ 232  442  358 8968]]
# LinearDiscriminantAnalysis
# ________________________________________________________________________________
# Training:
# Model with rank: 1
# Mean validation score: 0.719 (std: 0.018)
# Parameters: {'tol': 9.545484566618347e-05, 'solver': 'saga', 'multi_class': 'multinomial', 'C': 1000}
#
#
# train time: 10.779s
# test time:  0.003s
# accuracy:   0.634
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.55      0.39      0.46     10000
#            1       0.51      0.49      0.50     10000
#            2       0.62      0.75      0.68     10000
#            3       0.80      0.92      0.86     10000
#
#     accuracy                           0.63     40000
#    macro avg       0.62      0.63      0.62     40000
# weighted avg       0.62      0.63      0.62     40000
#
# confusion matrix:
# [[3879 3102 1991 1028]
#  [2231 4854 2262  653]
#  [ 696 1272 7465  567]
#  [ 229  258  346 9167]]
# LogisticRegression

# %%
import datetime
# Displaying results to paste into latex
for nc in range(9):
    print("\\begin{filecontents}{"+names[nc]+"-kraken.dat}\n noise 	snr accuracy") 
    for nl in range(len(noiselevel)):
        clf_descr, score, train_time, test_time, clf_rep, clf_cm=results[nl][nc]
    
        print(str(noiselevel[nl])+" "+ str(18-nl)+" "+ str(score*100))
    print("\end{filecontents}")
# Out:
# \begin{filecontents}{GaussianProcessClassifier-kraken.dat}
#  noise 	snr accuracy
# 15 18 81.065
# 17 17 81.1675
# 19 16 81.0975
# 21 15 80.79499999999999
# 26 14 79.55250000000001
# 30 13 78.14750000000001
# 32 12 78.05
# 33 11 76.92999999999999
# 60 10 63.465
# \end{filecontents}
# \begin{filecontents}{KNeighborsClassifier-kraken.dat}
#  noise 	snr accuracy
# 15 18 81.62
# 17 17 82.6875
# 19 16 82.515
# 21 15 81.15
# 26 14 79.4625
# 30 13 76.47
# 32 12 78.4725
# 33 11 74.8375
# 60 10 55.87
# \end{filecontents}
# \begin{filecontents}{NearestCentroid-kraken.dat}
#  noise 	snr accuracy
# 15 18 81.065
# 17 17 81.195
# 19 16 81.10000000000001
# 21 15 80.8175
# 26 14 79.55250000000001
# 30 13 78.14750000000001
# 32 12 78.0475
# 33 11 76.92750000000001
# 60 10 63.465
# \end{filecontents}
# \begin{filecontents}{SVC-kraken.dat}
#  noise 	snr accuracy
# 15 18 81.67999999999999
# 17 17 81.41000000000001
# 19 16 80.9
# 21 15 80.63749999999999
# 26 14 79.7975
# 30 13 78.4225
# 32 12 78.2475
# 33 11 76.5925
# 60 10 63.455
# \end{filecontents}
# \begin{filecontents}{SVC-kraken.dat}
#  noise 	snr accuracy
# 15 18 81.73
# 17 17 81.085
# 19 16 81.4775
# 21 15 80.695
# 26 14 79.455
# 30 13 77.9575
# 32 12 77.4725
# 33 11 76.60249999999999
# 60 10 63.607499999999995
# \end{filecontents}
# \begin{filecontents}{MLPClassifier-kraken.dat}
#  noise 	snr accuracy
# 15 18 82.9075
# 17 17 83.17
# 19 16 81.82249999999999
# 21 15 80.71249999999999
# 26 14 71.2175
# 30 13 79.9925
# 32 12 78.045
# 33 11 76.84
# 60 10 60.185
# \end{filecontents}
# \begin{filecontents}{DecisionTreeClassifier-kraken.dat}
#  noise 	snr accuracy
# 15 18 76.5175
# 17 17 76.11250000000001
# 19 16 76.37
# 21 15 74.4
# 26 14 69.2475
# 30 13 65.3275
# 32 12 66.61
# 33 11 63.144999999999996
# 60 10 44.817499999999995
# \end{filecontents}
# \begin{filecontents}{RandomForestClassifier-kraken.dat}
#  noise 	snr accuracy
# 15 18 81.3775
# 17 17 80.30000000000001
# 19 16 80.8925
# 21 15 79.7875
# 26 14 77.1875
# 30 13 75.64
# 32 12 77.01750000000001
# 33 11 73.195
# 60 10 57.2375
# \end{filecontents}
# \begin{filecontents}{GaussianNB-kraken.dat}
#  noise 	snr accuracy
# 15 18 81.0875
# 17 17 81.10000000000001
# 19 16 81.065
# 21 15 80.745
# 26 14 79.57
# 30 13 78.065
# 32 12 77.75999999999999
# 33 11 76.8925
# 60 10 63.33
# \end{filecontents}

# %%
# Displaying results in a pandas dataframe
#Code adapted from https://www.kaggle.com/grfiv4/displaying-the-results-of-a-grid-search
import pandas as pd
def score_summary(grid_searches, sort_by='mean_test_score'):
        frames = []
        for name, grid_search in grid_searches.items():
            frame = pd.DataFrame(grid_search.cv_results_)
            frame = frame.filter(regex='^(?!.*param_).*$')
            frame['estimator'] = len(frame)*[name]
            frames.append(frame)
        df = pd.concat(frames)
        
        df = df.sort_values([sort_by], ascending=False)
        df = df.reset_index()
        df = df.drop(['rank_test_score', 'index'], 1)
        
        columns = df.columns.tolist()
        columns.remove('estimator')
        columns = ['estimator']+columns
        df = df[columns]
        return df

# %%
df=score_summary(grid_searches[0])
print(noiselevel[0])
df
