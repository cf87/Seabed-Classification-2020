# %%
import numpy as np
import h5py
import scipy.io

# %%
# Loads KRAKEN data and returns, training, hold out validation, and test
def load_dataset(idx, shuffle, Ntrain):
    filepath = "files_116/files_VLA_rand_"+ str(idx) +"_116.mat"
    
    mat = scipy.io.loadmat(filepath)
    signal_train=np.array([], dtype=np.float)
  
    # Training data
    args = (mat['p_cl_n'], mat['p_si_n'], mat['p_sa_n'],mat['p_gr_n'])
    for v in args: 
        tmp=np.vstack([np.real(v), np.imag(v)]) 
        signal_train=np.hstack([signal_train, tmp]) if signal_train.size else tmp

    mats=[1500,  1575, 1650, 1800]
    labels_train=np.array([mats[int(np.floor(i/1000))] for i in range(4000)], dtype=np.float)
    
    # Test data
    signal_test=np.array([],dtype=np.float)
    labels_test=np.array([], dtype=np.float)
    
    for j in range(10):
        i=j+1
        args=(mat["p_cl_n"+str(i)], mat['p_si_n'+str(i)], mat["p_sa_n"+str(i)], mat["p_gr_n"+str(i)])
        for v in args: 
            tmp=np.vstack([np.real(v), np.imag(v)])
            signal_test=np.hstack([signal_test, tmp]) if signal_test.size else tmp

        labels_test=np.real(np.append([labels_test], [labels_train]))

    # Test labels are perturbed, associate them with the correct material type
    Y=labels_test
    labels=labels_test
    
    X = signal_train.transpose()
    y = labels_train
    X_test = signal_test.transpose()
    y_test = Y
    
    X = signal_train.transpose()
    y = labels_train
    X_test = signal_test.transpose()
    y_test = labels_test
    
   
    ind=range(len(y))
    ind_train=ind[1:Ntrain]
    ind_val=ind[Ntrain:len(y)]
    ind_test = range(len(y_test))

  
    if shuffle:
        ind1 = np.random.permutation(len(y))
        ind_train=ind1[0:Ntrain]
        ind_val=ind1[Ntrain:len(y)]
        ind_test = np.random.permutation(len(y_test))
    
    X_train = np.array(X[ind_train,:], dtype = np.float)
    y_train = np.array(y[ind_train],)   
    X_val = np.array(X[ind_val,:], dtype = np.float)
    y_val = np.array(y[ind_val],) 
    X_test = np.array(X_test[ind_test,:], dtype = np.float)
    y_test = np.array(y_test[ind_test],)  
    return X_train, y_train, X_val, y_val, X_test, y_test

# %%
# Plot the training and test data
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from matplotlib import cm


X_train, y_train, X_val, y_val, X_test, y_test = load_dataset(15,False, 3200)

f, ax = plt.subplots(2, 2, sharey=False, sharex=False)
ax[0][0].plot(X_train[:,4], color='orange')
ax[0][1].plot(y_train, color='yellow')
ax[1][0].plot(X_test[0:4000,20], color='green')
ax[1][1].plot(y_test, color='blue')

# %%
from time import time
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# Benchmark metrics for each classifier
# Adapted from Peter Prettenhofer, et. al,
# https://scikit-learn.org/0.19/auto_examples/text/document_classification_20newsgroups.html
def benchmark(clf):
    target_names=[]
    targets=np.unique(y_train);

    for i in range(len(targets)):
        target_names.append(np.str(targets[i]))
    print('_' * 80)
    print("Training: ")
    t0 = time()
    clf.fit(X_train, y_train)
    train_time = time() - t0
    print("train time: %0.3fs" % train_time)
    
    results=clf.cv_results_
    candidates = np.flatnonzero(results['rank_test_score'] == 1)
    for candidate in candidates:
        print("Model with rank: {0}".format(1))
        print("Mean validation score: {0:.3f} (std: {1:.3f})"
              .format(results['mean_test_score'][candidate],
                      results['std_test_score'][candidate]))
        print("Parameters: {0}".format(results['params'][candidate]))
        print("\n")
    print("Validation: ")
    pred=clf.predict(X_val)
    test_time = time() - t0
    #print(metrics.confusion_matrix(y_val, pred))
    #print(metrics.classification_report(y_val, pred, target_names=target_names))
    score = metrics.accuracy_score(y_val, pred)
    print("val score:   %0.3f" % score)
    
    print("Testing: ")
    t0 = time()
    pred = clf.predict(X_test)
    print("test time:  %0.3fs" % test_time)
    
    score = metrics.accuracy_score(y_test, pred)
    print("accuracy:   %0.3f" % score)
    print("classification report:")
    #print(metrics.classification_report(y_test, pred, target_names=target_names))
    print("confusion matrix:")
    print(metrics.confusion_matrix(y_test, pred))

    clf_descr = str(str(clf.estimator))
    clf_rep = str(metrics.classification_report(y_test, pred, target_names=target_names))
    clf_cm = str(metrics.confusion_matrix(y_test, pred))
    return clf_descr, score, train_time, test_time, clf_rep, clf_cm

# %%
from scipy.stats import randint as sp_randint
from scipy.stats import uniform, expon
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier, NearestCentroid
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis


# list of (estimator, param_dist), where param_dist is used  in RandomizedSearchCV
classifiers = [
#      (GaussianProcessClassifier(warm_start=True, n_jobs=-1, random_state=42),{
#         'multi_class': ["one_vs_rest", "one_vs_one"],
#         'n_restarts_optimizer':[0, 1]
#      }),
     (KNeighborsClassifier(), {
         'n_neighbors': sp_randint(8, 10),
         'weights': ['uniform', 'distance'],
         'algorithm':['ball_tree', 'kd_tree'],
     }),
    (NearestCentroid(), {
         'metric': ['euclidean', 'manhattan','minkowski','chebyshev'],
         'shrink_threshold': [None, .001, .0001, .1, .01]
     }),
    (SVC(kernel='linear'), {
        'C': np.logspace(-1, 3, 100),
        'tol': np.logspace(-8, -2, 100)
    }),
    (SVC(random_state=42, gamma='scale'), {
        'C': [.1, 1, 10, 100, 1000],
        'kernel': ['rbf', 'poly', 'linear', 'sigmoid'], 
        'class_weight':['balanced', None],
        'tol': np.logspace(-8, -2, 100)
    }),
    (MLPClassifier(max_iter=100000), {
        'hidden_layer_sizes': [(200), (50), (100,)],
        'alpha': expon(scale=.1),
        'learning_rate': ['constant','adaptive'],
    }),
    (DecisionTreeClassifier(),{
        'criterion': ['gini', 'entropy'],
        'splitter': ['best','random'],
        'max_features':[None, 'auto', 'sqrt', 'log2'],
    }),
    (RandomForestClassifier(max_depth=5, n_jobs=-1), {
        "max_depth": sp_randint(2, 20),
        "n_estimators": sp_randint(2, 50),
        "max_features": ['auto', 'log2'],
        'class_weight': ['balanced', 'balanced_subsample'],
        'criterion': ['gini', 'entropy']
    }),
     (GaussianNB(), {
         'var_smoothing': np.logspace(-12, -8, 100)
     }), 
     (LinearDiscriminantAnalysis(n_components=2), {
         'solver': ['svd', 'lsqr'],
         'tol': np.logspace(-10, -2, 100)
     }),
     (LogisticRegression(solver='newton-cg', random_state=0, max_iter=100000), {
        'C': [.1, 1, 10, 100, 1000],
         'multi_class': ["auto", "ovr","multinomial"],
         'solver': ['sag', 'saga', 'newton-cg'],
         'tol': np.logspace(-6, -4, 100)
     }),
]
names = [e.__class__.__name__ for e, g in classifiers]

# %%
# tests the classifiers without hyperparameter search
X_train, y_train,X_val, y_val, X_test, y_test= load_dataset(15, True, 3999)
X_val=X_train
y_val=y_train
target_names=[]
targets=np.unique(y_train);
for i in range(len(targets)):
        target_names.append(np.str(targets[i]))
        

j=1
(clf, param_grid)=classifiers[j]
name=names[j]
print(name)
clf.fit(X_train, y_train)
pred=clf.predict(X_val)
print(metrics.confusion_matrix(y_val, pred))
#print(metrics.classification_report(y_val, pred, target_names=target_names))
score = metrics.accuracy_score(y_val, pred)
print("val score:   %0.3f" % score)
pred=clf.predict(X_test)
print(metrics.confusion_matrix(y_test, pred))
#print(metrics.classification_report(y_test, pred, target_names=target_names))
score = metrics.accuracy_score(y_test, pred)
print("test score:   %0.3f" % score)
# Out:
# NearestCentroid
# [[ 995    5    0    0]
#  [   6  994    0    0]
#  [   0    0 1000    0]
#  [   0    0    0  999]]
# val score:   0.997
# [[ 2562  7406    31     1]
#  [   11  9935    54     0]
#  [    0    71  9929     0]
#  [    0     0     0 10000]]
# test score:   0.811

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.utils.testing import ignore_warnings
from sklearn.exceptions import ConvergenceWarning
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import train_test_split


data_name=['KRAKEN 2 layer']
dset_name=data_name

noiselevel = np.array([15, 17 ,19, 21, 26, 30, 32 ,33, 60])
grid_searches = [dict() for x in range(len(noiselevel))]
results = [[] for x in range(len(noiselevel))]
ds_cnt=-1
for nl in noiselevel:
    ds_cnt=ds_cnt+1
    X_train, y_train,X_val, y_val, X_test, y_test= load_dataset(nl, True, 3200)
    
    print('\n Noise level:', str(nl),'\n')
   
    # iterate over classifiers
    for est_idx, (name, (estimator, param_grid)) in \
        enumerate(zip(names, classifiers)):

        # Perform randomized grid search over possible hyperparameters
        clf = RandomizedSearchCV(estimator=estimator, param_distributions=param_grid, n_iter=20, cv=5,
                                 verbose=0, n_jobs=-1)
        
        with ignore_warnings(category=ConvergenceWarning):
            results[ds_cnt].append(benchmark(clf))
        grid_searches[ds_cnt][name] = clf

        # Make predictions for the four test cases
        print(name)
        
        #print('Test Score', str(clf.score(X_test, y_test)))
# Out:
#  Noise level: 15
#
# ________________________________________________________________________________
# Training:
# train time: 1.905s
# Model with rank: 1
# Mean validation score: 0.996 (std: 0.002)
# Parameters: {'algorithm': 'kd_tree', 'n_neighbors': 9, 'weights': 'uniform'}
#
#
# Model with rank: 1
# Mean validation score: 0.996 (std: 0.002)
# Parameters: {'algorithm': 'kd_tree', 'n_neighbors': 9, 'weights': 'uniform'}
#
#
# Model with rank: 1
# Mean validation score: 0.996 (std: 0.002)
# Parameters: {'algorithm': 'ball_tree', 'n_neighbors': 9, 'weights': 'distance'}
#
#
# Model with rank: 1
# Mean validation score: 0.996 (std: 0.002)
# Parameters: {'algorithm': 'ball_tree', 'n_neighbors': 9, 'weights': 'distance'}
#
#
# Model with rank: 1
# Mean validation score: 0.996 (std: 0.002)
# Parameters: {'algorithm': 'kd_tree', 'n_neighbors': 9, 'weights': 'uniform'}
#
#
# Model with rank: 1
# Mean validation score: 0.996 (std: 0.002)
# Parameters: {'algorithm': 'ball_tree', 'n_neighbors': 9, 'weights': 'distance'}
#
#
# Model with rank: 1
# Mean validation score: 0.996 (std: 0.002)
# Parameters: {'algorithm': 'ball_tree', 'n_neighbors': 9, 'weights': 'uniform'}
#
#
# Model with rank: 1
# Mean validation score: 0.996 (std: 0.002)
# Parameters: {'algorithm': 'ball_tree', 'n_neighbors': 9, 'weights': 'uniform'}
#
#
# Model with rank: 1
# Mean validation score: 0.996 (std: 0.002)
# Parameters: {'algorithm': 'ball_tree', 'n_neighbors': 9, 'weights': 'distance'}
#
#
# Validation:
# val score:   0.999
# Testing:
# test time:  2.026s
# accuracy:   0.818
# classification report:
# confusion matrix:
# [[ 2866  7097    37     0]
#  [   27  9907    66     0]
#  [    0    73  9927     0]
#  [    0     0     0 10000]]
# KNeighborsClassifier
# ________________________________________________________________________________
# Training:
# train time: 0.205s
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.003)
# Parameters: {'shrink_threshold': None, 'metric': 'euclidean'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.003)
# Parameters: {'shrink_threshold': 0.001, 'metric': 'euclidean'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.003)
# Parameters: {'shrink_threshold': 0.0001, 'metric': 'euclidean'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.003)
# Parameters: {'shrink_threshold': 0.1, 'metric': 'euclidean'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.003)
# Parameters: {'shrink_threshold': 0.01, 'metric': 'euclidean'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.003)
# Parameters: {'shrink_threshold': None, 'metric': 'minkowski'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.003)
# Parameters: {'shrink_threshold': 0.001, 'metric': 'minkowski'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.003)
# Parameters: {'shrink_threshold': 0.0001, 'metric': 'minkowski'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.003)
# Parameters: {'shrink_threshold': 0.1, 'metric': 'minkowski'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.003)
# Parameters: {'shrink_threshold': 0.01, 'metric': 'minkowski'}
#
#
# Validation:
# val score:   1.000
# Testing:
# test time:  0.209s
# accuracy:   0.810
# classification report:
# confusion matrix:
# [[ 2555  7413    31     1]
#  [   12  9936    52     0]
#  [    0    74  9926     0]
#  [    0     0     0 10000]]
# NearestCentroid
# ________________________________________________________________________________
# Training:
# train time: 2.758s
# Model with rank: 1
# Mean validation score: 0.953 (std: 0.007)
# Parameters: {'tol': 4.037017258596558e-08, 'C': 756.463327554629}
#
#
# Validation:
# val score:   0.999
# Testing:
# test time:  2.822s
# accuracy:   0.849
# classification report:
# confusion matrix:
# [[ 4154  5815    30     1]
#  [   55  9892    53     0]
#  [    0    74  9926     0]
#  [    0     0     0 10000]]
# SVC
# ________________________________________________________________________________
# Training:
# train time: 1.037s
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.003)
# Parameters: {'tol': 7.56463327554629e-05, 'kernel': 'sigmoid', 'class_weight': None, 'C': 0.1}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.003)
# Parameters: {'tol': 0.0014174741629268048, 'kernel': 'rbf', 'class_weight': 'balanced', 'C': 0.1}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.003)
# Parameters: {'tol': 0.0002009233002565046, 'kernel': 'rbf', 'class_weight': 'balanced', 'C': 0.1}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.003)
# Parameters: {'tol': 4.3287612810830616e-07, 'kernel': 'sigmoid', 'class_weight': 'balanced', 'C': 0.1}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.003)
# Parameters: {'tol': 1.072267222010323e-05, 'kernel': 'rbf', 'class_weight': None, 'C': 0.1}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.001)
# Parameters: {'tol': 2.310129700083158e-08, 'kernel': 'rbf', 'class_weight': 'balanced', 'C': 100}
#
#
# Validation:
# val score:   1.000
# Testing:
# test time:  1.068s
# accuracy:   0.810
# classification report:
# confusion matrix:
# [[ 2535  7444    20     1]
#  [   13  9917    70     0]
#  [    0    62  9938     0]
#  [    0     0     0 10000]]
# SVC
# ________________________________________________________________________________
# Training:
# /usr/local/lib/python3.7/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# train time: 217.971s
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.003)
# Parameters: {'alpha': 0.015046192029279143, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant'}
#
#
# Validation:
# val score:   0.999
# Testing:
# test time:  217.976s
# accuracy:   0.798
# classification report:
# confusion matrix:
# [[ 2331  7650    18     1]
#  [   43  9616   341     0]
#  [    0    13  9987     0]
#  [    0     0     0 10000]]
# MLPClassifier
# ________________________________________________________________________________
# Training:
# /usr/local/lib/python3.7/site-packages/sklearn/model_selection/_search.py:266: UserWarning: The total space of parameters 16 is smaller than n_iter=20. Running 16 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# train time: 0.301s
# Model with rank: 1
# Mean validation score: 0.951 (std: 0.008)
# Parameters: {'splitter': 'best', 'max_features': None, 'criterion': 'entropy'}
#
#
# Validation:
# val score:   0.961
# Testing:
# test time:  0.302s
# accuracy:   0.787
# classification report:
# confusion matrix:
# [[3329 5533 1128   10]
#  [ 346 8919  723   12]
#  [  50  624 9286   40]
#  [   3   51   12 9934]]
# DecisionTreeClassifier
# ________________________________________________________________________________
# Training:
# train time: 11.416s
# Model with rank: 1
# Mean validation score: 0.991 (std: 0.004)
# Parameters: {'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 19, 'max_features': 'log2', 'n_estimators': 32}
#
#
# Model with rank: 1
# Mean validation score: 0.991 (std: 0.003)
# Parameters: {'class_weight': 'balanced', 'criterion': 'gini', 'max_depth': 19, 'max_features': 'log2', 'n_estimators': 45}
#
#
# Validation:
# val score:   0.995
# Testing:
# test time:  11.522s
# accuracy:   0.821
# classification report:
# confusion matrix:
# [[3248 6642  107    3]
#  [  69 9784  147    0]
#  [   0  206 9794    0]
#  [   0    1    0 9999]]
# RandomForestClassifier
# ________________________________________________________________________________
# Training:
# train time: 0.207s
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.003)
# Parameters: {'var_smoothing': 4.229242874389499e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.003)
# Parameters: {'var_smoothing': 2.915053062825182e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.003)
# Parameters: {'var_smoothing': 7.742636826811278e-12}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.003)
# Parameters: {'var_smoothing': 1.4508287784959372e-12}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.003)
# Parameters: {'var_smoothing': 2.205130739903041e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.003)
# Parameters: {'var_smoothing': 3.5111917342151416e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.003)
# Parameters: {'var_smoothing': 5.994842503189421e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.003)
# Parameters: {'var_smoothing': 8.697490026177835e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.003)
# Parameters: {'var_smoothing': 7.56463327554629e-09}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.003)
# Parameters: {'var_smoothing': 2.4770763559917138e-09}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.003)
# Parameters: {'var_smoothing': 3.764935806792471e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.003)
# Parameters: {'var_smoothing': 2.848035868435805e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.003)
# Parameters: {'var_smoothing': 8.497534359086438e-12}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.003)
# Parameters: {'var_smoothing': 1.3219411484660287e-12}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.003)
# Parameters: {'var_smoothing': 2.257019719633917e-09}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.003)
# Parameters: {'var_smoothing': 2.983647240283334e-09}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.003)
# Parameters: {'var_smoothing': 1.176811952434999e-09}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.003)
# Parameters: {'var_smoothing': 9.770099572992246e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.003)
# Parameters: {'var_smoothing': 1.2045035402587836e-12}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.003)
# Parameters: {'var_smoothing': 1e-08}
#
#
# Validation:
# val score:   1.000
# Testing:
# test time:  0.215s
# accuracy:   0.812
# classification report:
# confusion matrix:
# [[ 2609  7367    23     1]
#  [   12  9939    49     0]
#  [    0    71  9929     0]
#  [    0     0     0 10000]]
# GaussianNB
# ________________________________________________________________________________
# Training:
# train time: 0.329s
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.002)
# Parameters: {'tol': 3.351602650938848e-06, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.002)
# Parameters: {'tol': 1.1233240329780266e-09, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.002)
# Parameters: {'tol': 4.4306214575838866e-10, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.002)
# Parameters: {'tol': 0.00024201282647943835, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.002)
# Parameters: {'tol': 3.7649358067924715e-05, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.002)
# Parameters: {'tol': 1.023531021899027e-05, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.002)
# Parameters: {'tol': 7.742636826811277e-10, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.002)
# Parameters: {'tol': 0.0001149756995397738, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.002)
# Parameters: {'tol': 0.0032745491628777316, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.002)
# Parameters: {'tol': 1.592282793341094e-06, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.002)
# Parameters: {'tol': 0.00042292428743895077, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.002)
# Parameters: {'tol': 4.132012400115335e-09, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.002)
# Parameters: {'tol': 8.111308307896873e-08, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.002)
# Parameters: {'tol': 7.924828983539186e-05, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.002)
# Parameters: {'tol': 1.0476157527896662e-08, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.002)
# Parameters: {'tol': 7.924828983539186e-05, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.002)
# Parameters: {'tol': 0.000200923300256505, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.002)
# Parameters: {'tol': 2.656087782946684e-08, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.002)
# Parameters: {'tol': 3.1992671377973846e-08, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.997 (std: 0.002)
# Parameters: {'tol': 1.592282793341094e-06, 'solver': 'svd'}
#
#
# Validation:
# val score:   0.999
# Testing:
# test time:  0.336s
# accuracy:   0.811
# classification report:
# confusion matrix:
# [[ 2601  7378    20     1]
#  [   12  9924    64     0]
#  [    0    70  9930     0]
#  [    0     0     0 10000]]
# LinearDiscriminantAnalysis
# ________________________________________________________________________________
# Training:
# train time: 10.576s
# Model with rank: 1
# Mean validation score: 0.988 (std: 0.005)
# Parameters: {'tol': 1.6297508346206434e-05, 'solver': 'saga', 'multi_class': 'auto', 'C': 1000}
#
#
# Model with rank: 1
# Mean validation score: 0.988 (std: 0.005)
# Parameters: {'tol': 2.0092330025650458e-06, 'solver': 'saga', 'multi_class': 'auto', 'C': 1000}
#
#
# Model with rank: 1
# Mean validation score: 0.988 (std: 0.005)
# Parameters: {'tol': 9.111627561154906e-05, 'solver': 'newton-cg', 'multi_class': 'multinomial', 'C': 1000}
#
#
# Validation:
# val score:   0.996
# Testing:
# test time:  10.578s
# accuracy:   0.879
# classification report:
# confusion matrix:
# [[ 5569  4249   178     4]
#  [  137  9608   255     0]
#  [    0    17  9983     0]
#  [    0     0     0 10000]]
# LogisticRegression
#
#  Noise level: 17
#
# ________________________________________________________________________________
# Training:
# train time: 0.735s
# Model with rank: 1
# Mean validation score: 0.992 (std: 0.002)
# Parameters: {'algorithm': 'ball_tree', 'n_neighbors': 8, 'weights': 'uniform'}
#
#
# Model with rank: 1
# Mean validation score: 0.992 (std: 0.002)
# Parameters: {'algorithm': 'ball_tree', 'n_neighbors': 9, 'weights': 'uniform'}
#
#
# Model with rank: 1
# Mean validation score: 0.992 (std: 0.002)
# Parameters: {'algorithm': 'kd_tree', 'n_neighbors': 9, 'weights': 'distance'}
#
#
# Model with rank: 1
# Mean validation score: 0.992 (std: 0.002)
# Parameters: {'algorithm': 'ball_tree', 'n_neighbors': 9, 'weights': 'uniform'}
#
#
# Model with rank: 1
# Mean validation score: 0.992 (std: 0.002)
# Parameters: {'algorithm': 'kd_tree', 'n_neighbors': 9, 'weights': 'distance'}
#
#
# Model with rank: 1
# Mean validation score: 0.992 (std: 0.002)
# Parameters: {'algorithm': 'kd_tree', 'n_neighbors': 9, 'weights': 'distance'}
#
#
# Model with rank: 1
# Mean validation score: 0.992 (std: 0.002)
# Parameters: {'algorithm': 'kd_tree', 'n_neighbors': 8, 'weights': 'uniform'}
#
#
# Model with rank: 1
# Mean validation score: 0.992 (std: 0.002)
# Parameters: {'algorithm': 'kd_tree', 'n_neighbors': 9, 'weights': 'uniform'}
#
#
# Model with rank: 1
# Mean validation score: 0.992 (std: 0.002)
# Parameters: {'algorithm': 'kd_tree', 'n_neighbors': 9, 'weights': 'distance'}
#
#
# Model with rank: 1
# Mean validation score: 0.992 (std: 0.002)
# Parameters: {'algorithm': 'ball_tree', 'n_neighbors': 8, 'weights': 'uniform'}
#
#
# Model with rank: 1
# Mean validation score: 0.992 (std: 0.002)
# Parameters: {'algorithm': 'ball_tree', 'n_neighbors': 9, 'weights': 'uniform'}
#
#
# Model with rank: 1
# Mean validation score: 0.992 (std: 0.002)
# Parameters: {'algorithm': 'kd_tree', 'n_neighbors': 9, 'weights': 'distance'}
#
#
# Model with rank: 1
# Mean validation score: 0.992 (std: 0.002)
# Parameters: {'algorithm': 'ball_tree', 'n_neighbors': 9, 'weights': 'distance'}
#
#
# Validation:
# val score:   0.993
# Testing:
# test time:  0.841s
# accuracy:   0.821
# classification report:
# confusion matrix:
# [[ 3160  6769    70     1]
#  [   63  9846    91     0]
#  [    0   175  9825     0]
#  [    0     0     0 10000]]
# KNeighborsClassifier
# ________________________________________________________________________________
# Training:
# train time: 0.199s
# Model with rank: 1
# Mean validation score: 0.996 (std: 0.003)
# Parameters: {'shrink_threshold': None, 'metric': 'euclidean'}
#
#
# Model with rank: 1
# Mean validation score: 0.996 (std: 0.003)
# Parameters: {'shrink_threshold': 0.001, 'metric': 'euclidean'}
#
#
# Model with rank: 1
# Mean validation score: 0.996 (std: 0.003)
# Parameters: {'shrink_threshold': 0.0001, 'metric': 'euclidean'}
#
#
# Model with rank: 1
# Mean validation score: 0.996 (std: 0.003)
# Parameters: {'shrink_threshold': 0.1, 'metric': 'euclidean'}
#
#
# Model with rank: 1
# Mean validation score: 0.996 (std: 0.003)
# Parameters: {'shrink_threshold': 0.01, 'metric': 'euclidean'}
#
#
# Model with rank: 1
# Mean validation score: 0.996 (std: 0.003)
# Parameters: {'shrink_threshold': None, 'metric': 'minkowski'}
#
#
# Model with rank: 1
# Mean validation score: 0.996 (std: 0.003)
# Parameters: {'shrink_threshold': 0.001, 'metric': 'minkowski'}
#
#
# Model with rank: 1
# Mean validation score: 0.996 (std: 0.003)
# Parameters: {'shrink_threshold': 0.0001, 'metric': 'minkowski'}
#
#
# Model with rank: 1
# Mean validation score: 0.996 (std: 0.003)
# Parameters: {'shrink_threshold': 0.1, 'metric': 'minkowski'}
#
#
# Model with rank: 1
# Mean validation score: 0.996 (std: 0.003)
# Parameters: {'shrink_threshold': 0.01, 'metric': 'minkowski'}
#
#
# Validation:
# val score:   0.996
# Testing:
# test time:  0.204s
# accuracy:   0.811
# classification report:
# confusion matrix:
# [[ 2706  7215    78     1]
#  [   31  9863   106     0]
#  [    0   114  9886     0]
#  [    0     0     0 10000]]
# NearestCentroid
# ________________________________________________________________________________
# Training:
# train time: 2.730s
# Model with rank: 1
# Mean validation score: 0.924 (std: 0.005)
# Parameters: {'tol': 3.053855508833412e-08, 'C': 689.2612104349702}
#
#
# Validation:
# val score:   0.985
# Testing:
# test time:  2.794s
# accuracy:   0.773
# classification report:
# confusion matrix:
# [[ 1158  8784    57     1]
#  [    6  9915    79     0]
#  [    0   141  9859     0]
#  [    0     0     0 10000]]
# SVC
# ________________________________________________________________________________
# Training:
# train time: 1.125s
# Model with rank: 1
# Mean validation score: 0.996 (std: 0.003)
# Parameters: {'tol': 0.0002009233002565046, 'kernel': 'linear', 'class_weight': 'balanced', 'C': 1000}
#
#
# Validation:
# val score:   0.996
# Testing:
# test time:  1.186s
# accuracy:   0.809
# classification report:
# confusion matrix:
# [[ 2613  7322    64     1]
#  [   28  9880    92     0]
#  [    0   123  9877     0]
#  [    0     0     0 10000]]
# SVC
# ________________________________________________________________________________
# Training:
# /usr/local/lib/python3.7/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# train time: 423.173s
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.003)
# Parameters: {'alpha': 0.0015408974605549332, 'hidden_layer_sizes': 200, 'learning_rate': 'adaptive'}
#
#
# Validation:
# val score:   0.994
# Testing:
# test time:  423.182s
# accuracy:   0.809
# classification report:
# confusion matrix:
# [[ 2591  7311    87    11]
#  [   15  9853   132     0]
#  [    0    97  9903     0]
#  [    0     0     0 10000]]
# MLPClassifier
# ________________________________________________________________________________
# Training:
# /usr/local/lib/python3.7/site-packages/sklearn/model_selection/_search.py:266: UserWarning: The total space of parameters 16 is smaller than n_iter=20. Running 16 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# train time: 0.308s
# Model with rank: 1
# Mean validation score: 0.919 (std: 0.008)
# Parameters: {'splitter': 'best', 'max_features': None, 'criterion': 'gini'}
#
#
# Validation:
# val score:   0.927
# Testing:
# test time:  0.309s
# accuracy:   0.756
# classification report:
# confusion matrix:
# [[2926 5817 1076  181]
#  [ 519 8531  924   26]
#  [  39  856 9066   39]
#  [  14  140  114 9732]]
# DecisionTreeClassifier
# ________________________________________________________________________________
# Training:
# train time: 12.844s
# Model with rank: 1
# Mean validation score: 0.986 (std: 0.004)
# Parameters: {'class_weight': 'balanced_subsample', 'criterion': 'entropy', 'max_depth': 18, 'max_features': 'auto', 'n_estimators': 38}
#
#
# Validation:
# val score:   0.983
# Testing:
# test time:  12.959s
# accuracy:   0.814
# classification report:
# confusion matrix:
# [[3202 6628  160   10]
#  [ 123 9647  230    0]
#  [   1  276 9723    0]
#  [   0    2    0 9998]]
# RandomForestClassifier
# ________________________________________________________________________________
# Training:
# train time: 0.211s
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.004)
# Parameters: {'var_smoothing': 3.0538555088334124e-12}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.004)
# Parameters: {'var_smoothing': 1.1497569953977356e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.004)
# Parameters: {'var_smoothing': 8.497534359086438e-12}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.004)
# Parameters: {'var_smoothing': 4.7508101621027936e-09}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.004)
# Parameters: {'var_smoothing': 2.420128264794383e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.004)
# Parameters: {'var_smoothing': 8.697490026177835e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.004)
# Parameters: {'var_smoothing': 2.848035868435805e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.004)
# Parameters: {'var_smoothing': 2.0092330025650458e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.004)
# Parameters: {'var_smoothing': 8.902150854450393e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.004)
# Parameters: {'var_smoothing': 2.3644894126454073e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.004)
# Parameters: {'var_smoothing': 3.2745491628777316e-09}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.004)
# Parameters: {'var_smoothing': 7.924828983539185e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.004)
# Parameters: {'var_smoothing': 1.0235310218990269e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.004)
# Parameters: {'var_smoothing': 5.336699231206302e-12}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.004)
# Parameters: {'var_smoothing': 9.111627561154905e-09}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.004)
# Parameters: {'var_smoothing': 3.6783797718286346e-12}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.004)
# Parameters: {'var_smoothing': 4.132012400115335e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.004)
# Parameters: {'var_smoothing': 1.176811952434999e-09}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.004)
# Parameters: {'var_smoothing': 9.770099572992246e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.004)
# Parameters: {'var_smoothing': 6.428073117284319e-12}
#
#
# Validation:
# val score:   0.996
# Testing:
# test time:  0.219s
# accuracy:   0.813
# classification report:
# confusion matrix:
# [[ 2765  7167    67     1]
#  [   34  9861   105     0]
#  [    0   116  9884     0]
#  [    0     0     0 10000]]
# GaussianNB
# ________________________________________________________________________________
# Training:
# train time: 0.344s
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.003)
# Parameters: {'tol': 0.0012915496650148853, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.003)
# Parameters: {'tol': 0.0018738174228603867, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.003)
# Parameters: {'tol': 7.2208090183854565e-09, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.003)
# Parameters: {'tol': 0.008302175681319753, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.003)
# Parameters: {'tol': 6.428073117284319e-10, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.003)
# Parameters: {'tol': 7.924828983539186e-05, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.003)
# Parameters: {'tol': 7.0548023107186455e-06, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.003)
# Parameters: {'tol': 0.004750810162102803, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.003)
# Parameters: {'tol': 4.977023564332114e-09, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.003)
# Parameters: {'tol': 5.214008287999695e-07, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.003)
# Parameters: {'tol': 0.0032745491628777316, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.003)
# Parameters: {'tol': 0.0001668100537200059, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.003)
# Parameters: {'tol': 1.2328467394420684e-05, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.003)
# Parameters: {'tol': 3.7649358067924715e-05, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.003)
# Parameters: {'tol': 3.1992671377973846e-08, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.003)
# Parameters: {'tol': 1.261856883066021e-08, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.003)
# Parameters: {'tol': 2.848035868435805e-09, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.003)
# Parameters: {'tol': 2.2051307399030457e-08, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.003)
# Parameters: {'tol': 0.000739072203352579, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.995 (std: 0.003)
# Parameters: {'tol': 0.0006135907273413176, 'solver': 'svd'}
#
#
# Validation:
# val score:   0.996
# Testing:
# test time:  0.352s
# accuracy:   0.810
# classification report:
# confusion matrix:
# [[ 2668  7279    52     1]
#  [   32  9849   119     0]
#  [    0   100  9900     0]
#  [    0     0     0 10000]]
# LinearDiscriminantAnalysis
# ________________________________________________________________________________
# Training:
# train time: 11.676s
# Model with rank: 1
# Mean validation score: 0.994 (std: 0.004)
# Parameters: {'tol': 1.788649529057435e-05, 'solver': 'saga', 'multi_class': 'multinomial', 'C': 100}
#
#
# Model with rank: 1
# Mean validation score: 0.994 (std: 0.004)
# Parameters: {'tol': 2.2570197196339216e-05, 'solver': 'saga', 'multi_class': 'multinomial', 'C': 100}
#
#
# Model with rank: 1
# Mean validation score: 0.994 (std: 0.004)
# Parameters: {'tol': 6.1359072734131755e-06, 'solver': 'sag', 'multi_class': 'auto', 'C': 100}
#
#
# Model with rank: 1
# Mean validation score: 0.994 (std: 0.004)
# Parameters: {'tol': 3.4304692863149194e-05, 'solver': 'newton-cg', 'multi_class': 'auto', 'C': 100}
#
#
# Validation:
# val score:   0.991
# Testing:
# test time:  11.678s
# accuracy:   0.842
# classification report:
# confusion matrix:
# [[ 3985  5878    91    46]
#  [   84  9789   126     1]
#  [    0   106  9892     2]
#  [    0     0     0 10000]]
# LogisticRegression
#
#  Noise level: 19
#
# ________________________________________________________________________________
# Training:
# train time: 0.787s
# Model with rank: 1
# Mean validation score: 0.983 (std: 0.005)
# Parameters: {'algorithm': 'ball_tree', 'n_neighbors': 8, 'weights': 'uniform'}
#
#
# Model with rank: 1
# Mean validation score: 0.983 (std: 0.005)
# Parameters: {'algorithm': 'ball_tree', 'n_neighbors': 8, 'weights': 'uniform'}
#
#
# Model with rank: 1
# Mean validation score: 0.983 (std: 0.005)
# Parameters: {'algorithm': 'kd_tree', 'n_neighbors': 8, 'weights': 'uniform'}
#
#
# Validation:
# val score:   0.984
# Testing:
# test time:  0.892s
# accuracy:   0.819
# classification report:
# confusion matrix:
# [[ 3358  6488   153     1]
#  [  171  9659   170     0]
#  [    0   260  9740     0]
#  [    0     0     0 10000]]
# KNeighborsClassifier
# ________________________________________________________________________________
# Training:
# train time: 0.207s
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'shrink_threshold': 0.01, 'metric': 'euclidean'}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'shrink_threshold': 0.01, 'metric': 'minkowski'}
#
#
# Validation:
# val score:   0.993
# Testing:
# test time:  0.209s
# accuracy:   0.806
# classification report:
# confusion matrix:
# [[ 2643  7239   117     1]
#  [   67  9761   172     0]
#  [    0   160  9840     0]
#  [    0     0     0 10000]]
# NearestCentroid
# ________________________________________________________________________________
# Training:
# train time: 2.630s
# Model with rank: 1
# Mean validation score: 0.991 (std: 0.004)
# Parameters: {'tol': 2.1544346900318867e-05, 'C': 1000.0}
#
#
# Validation:
# val score:   0.993
# Testing:
# test time:  2.690s
# accuracy:   0.807
# classification report:
# confusion matrix:
# [[ 2677  7207   115     1]
#  [   68  9760   172     0]
#  [    0   155  9845     0]
#  [    0     0     0 10000]]
# SVC
# ________________________________________________________________________________
# Training:
# train time: 1.671s
# Model with rank: 1
# Mean validation score: 0.989 (std: 0.003)
# Parameters: {'tol': 8.697490026177834e-05, 'kernel': 'rbf', 'class_weight': None, 'C': 0.1}
#
#
# Model with rank: 1
# Mean validation score: 0.989 (std: 0.003)
# Parameters: {'tol': 4.641588833612782e-06, 'kernel': 'rbf', 'class_weight': None, 'C': 0.1}
#
#
# Model with rank: 1
# Mean validation score: 0.989 (std: 0.003)
# Parameters: {'tol': 5.3366992312063125e-08, 'kernel': 'rbf', 'class_weight': None, 'C': 0.1}
#
#
# Validation:
# val score:   0.991
# Testing:
# test time:  1.715s
# accuracy:   0.803
# classification report:
# confusion matrix:
# [[ 2506  7421    72     1]
#  [   62  9771   167     0]
#  [    0   174  9826     0]
#  [    0     0     0 10000]]
# SVC
# ________________________________________________________________________________
# Training:
# /usr/local/lib/python3.7/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# train time: 339.203s
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.003)
# Parameters: {'alpha': 0.0075399386579231426, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive'}
#
#
# Validation:
# val score:   0.989
# Testing:
# test time:  339.209s
# accuracy:   0.817
# classification report:
# confusion matrix:
# [[ 3138  6791    60    11]
#  [  112  9754   134     0]
#  [    0   195  9805     0]
#  [    0     0     0 10000]]
# MLPClassifier
# ________________________________________________________________________________
# Training:
# /usr/local/lib/python3.7/site-packages/sklearn/model_selection/_search.py:266: UserWarning: The total space of parameters 16 is smaller than n_iter=20. Running 16 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# train time: 0.317s
# Model with rank: 1
# Mean validation score: 0.905 (std: 0.008)
# Parameters: {'splitter': 'best', 'max_features': None, 'criterion': 'entropy'}
#
#
# Validation:
# val score:   0.897
# Testing:
# test time:  0.318s
# accuracy:   0.737
# classification report:
# confusion matrix:
# [[2738 5796 1385   81]
#  [ 613 8185 1155   47]
#  [  32 1077 8826   65]
#  [   6  157  104 9733]]
# DecisionTreeClassifier
# ________________________________________________________________________________
# Training:
# train time: 5.710s
# Model with rank: 1
# Mean validation score: 0.976 (std: 0.003)
# Parameters: {'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 13, 'max_features': 'log2', 'n_estimators': 30}
#
#
# Validation:
# val score:   0.968
# Testing:
# test time:  5.815s
# accuracy:   0.801
# classification report:
# confusion matrix:
# [[3058 6703  224   15]
#  [ 246 9402  351    1]
#  [   2  389 9608    1]
#  [   0    9    2 9989]]
# RandomForestClassifier
# ________________________________________________________________________________
# Training:
# train time: 0.209s
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'var_smoothing': 1.3848863713938747e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'var_smoothing': 1.8307382802953697e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'var_smoothing': 6.734150657750828e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'var_smoothing': 5.994842503189421e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'var_smoothing': 5.72236765935022e-09}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'var_smoothing': 7.924828983539185e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'var_smoothing': 2.310129700083158e-12}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'var_smoothing': 2.205130739903041e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'var_smoothing': 2.848035868435805e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'var_smoothing': 2.656087782946684e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'var_smoothing': 1.7073526474706886e-09}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'var_smoothing': 1.9630406500402685e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'var_smoothing': 3.5111917342151416e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'var_smoothing': 1.2328467394420685e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'var_smoothing': 2.1049041445120218e-12}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'var_smoothing': 1.2618568830660183e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'var_smoothing': 3.0538555088334124e-12}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'var_smoothing': 1.6681005372000558e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'var_smoothing': 1.4849682622544636e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'var_smoothing': 7.390722033525775e-10}
#
#
# Validation:
# val score:   0.991
# Testing:
# test time:  0.216s
# accuracy:   0.802
# classification report:
# confusion matrix:
# [[ 2489  7398   112     1]
#  [   63  9758   179     0]
#  [    0   163  9837     0]
#  [    0     0     0 10000]]
# GaussianNB
# ________________________________________________________________________________
# Training:
# train time: 0.372s
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'tol': 4.977023564332114e-09, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'tol': 2.5353644939701164e-10, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'tol': 0.0008902150854450393, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'tol': 5.994842503189421e-09, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'tol': 2.656087782946684e-08, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'tol': 0.000200923300256505, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'tol': 6.428073117284319e-10, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'tol': 2.364489412645407e-09, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'tol': 7.924828983539186e-05, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'tol': 0.004750810162102803, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'tol': 3.125715849688242e-05, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'tol': 3.125715849688242e-05, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'tol': 3.351602650938848e-06, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'tol': 0.0039442060594376644, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'tol': 4.862601580065354e-06, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'tol': 0.000739072203352579, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'tol': 1.7073526474706922e-07, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'tol': 7.742636826811277e-10, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'tol': 3.5938136638046254e-07, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.990 (std: 0.004)
# Parameters: {'tol': 7.2208090183854565e-09, 'solver': 'svd'}
#
#
# Validation:
# val score:   0.994
# Testing:
# test time:  0.379s
# accuracy:   0.805
# classification report:
# confusion matrix:
# [[ 2593  7304   102     1]
#  [   62  9746   192     0]
#  [    0   143  9857     0]
#  [    0     0     0 10000]]
# LinearDiscriminantAnalysis
# ________________________________________________________________________________
# Training:
# train time: 2.621s
# Model with rank: 1
# Mean validation score: 0.964 (std: 0.007)
# Parameters: {'tol': 2.104904144512022e-06, 'solver': 'newton-cg', 'multi_class': 'ovr', 'C': 1000}
#
#
# Validation:
# val score:   0.968
# Testing:
# test time:  2.623s
# accuracy:   0.852
# classification report:
# confusion matrix:
# [[ 5554  3721   663    62]
#  [  570  8531   898     1]
#  [    1    24  9975     0]
#  [    0     0     0 10000]]
# LogisticRegression
#
#  Noise level: 21
#
# ________________________________________________________________________________
# Training:
# train time: 0.656s
# Model with rank: 1
# Mean validation score: 0.973 (std: 0.004)
# Parameters: {'algorithm': 'kd_tree', 'n_neighbors': 9, 'weights': 'distance'}
#
#
# Model with rank: 1
# Mean validation score: 0.973 (std: 0.004)
# Parameters: {'algorithm': 'kd_tree', 'n_neighbors': 9, 'weights': 'distance'}
#
#
# Model with rank: 1
# Mean validation score: 0.973 (std: 0.004)
# Parameters: {'algorithm': 'kd_tree', 'n_neighbors': 9, 'weights': 'distance'}
#
#
# Validation:
# val score:   0.979
# Testing:
# test time:  0.788s
# accuracy:   0.815
# classification report:
# confusion matrix:
# [[3483 6163  351    3]
#  [ 249 9415  336    0]
#  [   1  294 9704    1]
#  [   0    1    0 9999]]
# KNeighborsClassifier
# ________________________________________________________________________________
# Training:
# train time: 0.204s
# Model with rank: 1
# Mean validation score: 0.982 (std: 0.002)
# Parameters: {'shrink_threshold': None, 'metric': 'euclidean'}
#
#
# Model with rank: 1
# Mean validation score: 0.982 (std: 0.002)
# Parameters: {'shrink_threshold': 0.001, 'metric': 'euclidean'}
#
#
# Model with rank: 1
# Mean validation score: 0.982 (std: 0.002)
# Parameters: {'shrink_threshold': 0.0001, 'metric': 'euclidean'}
#
#
# Model with rank: 1
# Mean validation score: 0.982 (std: 0.002)
# Parameters: {'shrink_threshold': 0.01, 'metric': 'euclidean'}
#
#
# Model with rank: 1
# Mean validation score: 0.982 (std: 0.002)
# Parameters: {'shrink_threshold': None, 'metric': 'minkowski'}
#
#
# Model with rank: 1
# Mean validation score: 0.982 (std: 0.002)
# Parameters: {'shrink_threshold': 0.001, 'metric': 'minkowski'}
#
#
# Model with rank: 1
# Mean validation score: 0.982 (std: 0.002)
# Parameters: {'shrink_threshold': 0.0001, 'metric': 'minkowski'}
#
#
# Model with rank: 1
# Mean validation score: 0.982 (std: 0.002)
# Parameters: {'shrink_threshold': 0.01, 'metric': 'minkowski'}
#
#
# Validation:
# val score:   0.981
# Testing:
# test time:  0.207s
# accuracy:   0.808
# classification report:
# confusion matrix:
# [[2969 6827  202    2]
#  [ 141 9605  254    0]
#  [   1  241 9758    0]
#  [   0    1    0 9999]]
# NearestCentroid
# ________________________________________________________________________________
# Training:
# train time: 2.774s
# Model with rank: 1
# Mean validation score: 0.757 (std: 0.002)
# Parameters: {'tol': 7.054802310718646e-08, 'C': 432.87612810830615}
#
#
# Validation:
# val score:   0.802
# Testing:
# test time:  2.844s
# accuracy:   0.815
# classification report:
# confusion matrix:
# [[9046  602  350    2]
#  [5849 3690  461    0]
#  [  49   76 9875    0]
#  [   0    1    0 9999]]
# SVC
# ________________________________________________________________________________
# Training:
# train time: 1.841s
# Model with rank: 1
# Mean validation score: 0.983 (std: 0.003)
# Parameters: {'tol': 1.519911082952933e-06, 'kernel': 'linear', 'class_weight': None, 'C': 1000}
#
#
# Validation:
# val score:   0.985
# Testing:
# test time:  1.905s
# accuracy:   0.812
# classification report:
# confusion matrix:
# [[3143 6652  203    2]
#  [ 160 9577  263    0]
#  [   1  226 9773    0]
#  [   0    1    0 9999]]
# SVC
# ________________________________________________________________________________
# Training:
# /usr/local/lib/python3.7/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# train time: 238.427s
# Model with rank: 1
# Mean validation score: 0.982 (std: 0.003)
# Parameters: {'alpha': 0.0033628744587802964, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive'}
#
#
# Validation:
# val score:   0.988
# Testing:
# test time:  238.432s
# accuracy:   0.799
# classification report:
# confusion matrix:
# [[ 2543  7233   208    16]
#  [   91  9583   325     1]
#  [    0   182  9818     0]
#  [    0     0     0 10000]]
# MLPClassifier
# ________________________________________________________________________________
# Training:
# /usr/local/lib/python3.7/site-packages/sklearn/model_selection/_search.py:266: UserWarning: The total space of parameters 16 is smaller than n_iter=20. Running 16 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# train time: 0.334s
# Model with rank: 1
# Mean validation score: 0.870 (std: 0.018)
# Parameters: {'splitter': 'best', 'max_features': None, 'criterion': 'entropy'}
#
#
# Validation:
# val score:   0.868
# Testing:
# test time:  0.336s
# accuracy:   0.736
# classification report:
# confusion matrix:
# [[3359 5606  868  167]
#  [ 924 7654 1365   57]
#  [  86 1188 8636   90]
#  [  27  163   36 9774]]
# DecisionTreeClassifier
# ________________________________________________________________________________
# Training:
# train time: 12.928s
# Model with rank: 1
# Mean validation score: 0.960 (std: 0.007)
# Parameters: {'class_weight': 'balanced_subsample', 'criterion': 'entropy', 'max_depth': 12, 'max_features': 'auto', 'n_estimators': 46}
#
#
# Validation:
# val score:   0.961
# Testing:
# test time:  13.037s
# accuracy:   0.795
# classification report:
# confusion matrix:
# [[3211 6465  271   53]
#  [ 403 9096  489   12]
#  [   3  458 9527   12]
#  [   1   22    2 9975]]
# RandomForestClassifier
# ________________________________________________________________________________
# Training:
# train time: 0.210s
# Model with rank: 1
# Mean validation score: 0.981 (std: 0.002)
# Parameters: {'var_smoothing': 1.2328467394420685e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.981 (std: 0.002)
# Parameters: {'var_smoothing': 2.205130739903041e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.981 (std: 0.002)
# Parameters: {'var_smoothing': 3.4304692863149264e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.981 (std: 0.002)
# Parameters: {'var_smoothing': 1.788649529057435e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.981 (std: 0.002)
# Parameters: {'var_smoothing': 1.9630406500402685e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.981 (std: 0.002)
# Parameters: {'var_smoothing': 3.764935806792471e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.981 (std: 0.002)
# Parameters: {'var_smoothing': 5.336699231206302e-12}
#
#
# Model with rank: 1
# Mean validation score: 0.981 (std: 0.002)
# Parameters: {'var_smoothing': 3.1992671377973845e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.981 (std: 0.002)
# Parameters: {'var_smoothing': 2.4770763559917138e-09}
#
#
# Model with rank: 1
# Mean validation score: 0.981 (std: 0.002)
# Parameters: {'var_smoothing': 1.2915496650148826e-09}
#
#
# Model with rank: 1
# Mean validation score: 0.981 (std: 0.002)
# Parameters: {'var_smoothing': 1.176811952434999e-09}
#
#
# Model with rank: 1
# Mean validation score: 0.981 (std: 0.002)
# Parameters: {'var_smoothing': 4.03701725859655e-12}
#
#
# Model with rank: 1
# Mean validation score: 0.981 (std: 0.002)
# Parameters: {'var_smoothing': 1.5199110829529332e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.981 (std: 0.002)
# Parameters: {'var_smoothing': 9.545484566618327e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.981 (std: 0.002)
# Parameters: {'var_smoothing': 5.462277217684337e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.981 (std: 0.002)
# Parameters: {'var_smoothing': 6.734150657750828e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.981 (std: 0.002)
# Parameters: {'var_smoothing': 6.135907273413189e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.981 (std: 0.002)
# Parameters: {'var_smoothing': 1.747528400007683e-12}
#
#
# Model with rank: 1
# Mean validation score: 0.981 (std: 0.002)
# Parameters: {'var_smoothing': 1.0476157527896662e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.981 (std: 0.002)
# Parameters: {'var_smoothing': 2.310129700083158e-12}
#
#
# Validation:
# val score:   0.983
# Testing:
# test time:  0.218s
# accuracy:   0.807
# classification report:
# confusion matrix:
# [[2915 6905  178    2]
#  [ 140 9601  259    0]
#  [   1  239 9760    0]
#  [   0    1    0 9999]]
# GaussianNB
# ________________________________________________________________________________
# Training:
# train time: 0.350s
# Model with rank: 1
# Mean validation score: 0.982 (std: 0.002)
# Parameters: {'tol': 7.2208090183854565e-09, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.982 (std: 0.002)
# Parameters: {'tol': 1.261856883066021e-08, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.982 (std: 0.002)
# Parameters: {'tol': 2.364489412645407e-09, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.982 (std: 0.002)
# Parameters: {'tol': 0.0001149756995397738, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.982 (std: 0.002)
# Parameters: {'tol': 0.0010722672220103253, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.982 (std: 0.002)
# Parameters: {'tol': 0.0010722672220103253, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.982 (std: 0.002)
# Parameters: {'tol': 3.430469286314926e-09, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.982 (std: 0.002)
# Parameters: {'tol': 7.564633275546291e-07, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.982 (std: 0.002)
# Parameters: {'tol': 0.0039442060594376644, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.982 (std: 0.002)
# Parameters: {'tol': 1.1233240329780266e-09, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.982 (std: 0.002)
# Parameters: {'tol': 0.00024201282647943835, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.982 (std: 0.002)
# Parameters: {'tol': 3.351602650938848e-06, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.982 (std: 0.002)
# Parameters: {'tol': 1.2328467394420684e-05, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.982 (std: 0.002)
# Parameters: {'tol': 5.336699231206302e-10, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.982 (std: 0.002)
# Parameters: {'tol': 3.1992671377973846e-08, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.982 (std: 0.002)
# Parameters: {'tol': 2.782559402207126e-06, 'solver': 'svd'}
#
#
# Model with rank: 1
# ...
#
#
# Model with rank: 1
# Mean validation score: 0.907 (std: 0.011)
# Parameters: {'var_smoothing': 1.3530477745798076e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.907 (std: 0.011)
# Parameters: {'var_smoothing': 4.6415888336127913e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.907 (std: 0.011)
# Parameters: {'var_smoothing': 1.0722672220103253e-09}
#
#
# Model with rank: 1
# Mean validation score: 0.907 (std: 0.011)
# Parameters: {'var_smoothing': 1.2915496650148826e-09}
#
#
# Model with rank: 1
# Mean validation score: 0.907 (std: 0.011)
# Parameters: {'var_smoothing': 8.902150854450393e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.907 (std: 0.011)
# Parameters: {'var_smoothing': 8.497534359086438e-12}
#
#
# Model with rank: 1
# Mean validation score: 0.907 (std: 0.011)
# Parameters: {'var_smoothing': 1.3848863713938747e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.907 (std: 0.011)
# Parameters: {'var_smoothing': 5.72236765935022e-09}
#
#
# Model with rank: 1
# Mean validation score: 0.907 (std: 0.011)
# Parameters: {'var_smoothing': 1.2328467394420685e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.907 (std: 0.011)
# Parameters: {'var_smoothing': 4.8626015800653536e-12}
#
#
# Model with rank: 1
# Mean validation score: 0.907 (std: 0.011)
# Parameters: {'var_smoothing': 5.994842503189421e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.907 (std: 0.011)
# Parameters: {'var_smoothing': 7.390722033525775e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.907 (std: 0.011)
# Parameters: {'var_smoothing': 2.0092330025650458e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.907 (std: 0.011)
# Parameters: {'var_smoothing': 2.257019719633917e-09}
#
#
# Model with rank: 1
# Mean validation score: 0.907 (std: 0.011)
# Parameters: {'var_smoothing': 2.983647240283334e-09}
#
#
# Model with rank: 1
# Mean validation score: 0.907 (std: 0.011)
# Parameters: {'var_smoothing': 2.7825594022071257e-12}
#
#
# Validation:
# val score:   0.914
# Testing:
# test time:  0.223s
# accuracy:   0.769
# classification report:
# confusion matrix:
# [[3508 5625  785   82]
#  [ 819 8250  919   12]
#  [  65  842 9071   22]
#  [   8   28   19 9945]]
# GaussianNB
# ________________________________________________________________________________
# Training:
# train time: 0.328s
# Model with rank: 1
# Mean validation score: 0.907 (std: 0.005)
# Parameters: {'tol': 0.0002915053062825182, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.907 (std: 0.005)
# Parameters: {'tol': 0.01, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.907 (std: 0.005)
# Parameters: {'tol': 1.788649529057435e-05, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.907 (std: 0.005)
# Parameters: {'tol': 1.1768119524349991e-07, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.907 (std: 0.005)
# Parameters: {'tol': 8.111308307896873e-08, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.907 (std: 0.005)
# Parameters: {'tol': 1.3219411484660314e-06, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.907 (std: 0.005)
# Parameters: {'tol': 0.0003511191734215135, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.907 (std: 0.005)
# Parameters: {'tol': 1.3530477745798075e-09, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.907 (std: 0.005)
# Parameters: {'tol': 1.1233240329780266e-09, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.907 (std: 0.005)
# Parameters: {'tol': 3.8535285937105354e-08, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.907 (std: 0.005)
# Parameters: {'tol': 6.734150657750828e-08, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.907 (std: 0.005)
# Parameters: {'tol': 0.002718588242732946, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.907 (std: 0.005)
# Parameters: {'tol': 2.104904144512022e-10, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.907 (std: 0.005)
# Parameters: {'tol': 5.857020818056673e-06, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.907 (std: 0.005)
# Parameters: {'tol': 5.994842503189421e-09, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.907 (std: 0.005)
# Parameters: {'tol': 0.0001149756995397738, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.907 (std: 0.005)
# Parameters: {'tol': 1.0476157527896662e-08, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.907 (std: 0.005)
# Parameters: {'tol': 0.0015556761439304754, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.907 (std: 0.005)
# Parameters: {'tol': 2.477076355991714e-07, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.907 (std: 0.005)
# Parameters: {'tol': 6.28029144183426e-07, 'solver': 'lsqr'}
#
#
# Validation:
# val score:   0.916
# Testing:
# test time:  0.335s
# accuracy:   0.767
# classification report:
# confusion matrix:
# [[3439 5747  731   83]
#  [ 771 8237  976   16]
#  [  58  844 9081   17]
#  [  10   38   23 9929]]
# LinearDiscriminantAnalysis
# ________________________________________________________________________________
# Training:
# train time: 17.447s
# Model with rank: 1
# Mean validation score: 0.882 (std: 0.006)
# Parameters: {'tol': 8.111308307896873e-06, 'solver': 'sag', 'multi_class': 'ovr', 'C': 1000}
#
#
# Model with rank: 1
# Mean validation score: 0.882 (std: 0.006)
# Parameters: {'tol': 3.4304692863149194e-05, 'solver': 'sag', 'multi_class': 'ovr', 'C': 1000}
#
#
# Validation:
# val score:   0.886
# Testing:
# test time:  17.449s
# accuracy:   0.774
# classification report:
# confusion matrix:
# [[5118 3103 1355  424]
#  [1774 6377 1704  145]
#  [ 111  330 9488   71]
#  [   4    3    6 9987]]
# LogisticRegression
#
#  Noise level: 60
#
# ________________________________________________________________________________
# Training:
# train time: 0.699s
# Model with rank: 1
# Mean validation score: 0.625 (std: 0.009)
# Parameters: {'algorithm': 'ball_tree', 'n_neighbors': 9, 'weights': 'distance'}
#
#
# Model with rank: 1
# Mean validation score: 0.625 (std: 0.009)
# Parameters: {'algorithm': 'kd_tree', 'n_neighbors': 9, 'weights': 'distance'}
#
#
# Validation:
# val score:   0.611
# Testing:
# test time:  0.794s
# accuracy:   0.557
# classification report:
# confusion matrix:
# [[3322 3843 1908  927]
#  [2293 4803 2302  602]
#  [ 929 2479 5920  672]
#  [ 358  790  626 8226]]
# KNeighborsClassifier
# ________________________________________________________________________________
# Training:
# train time: 0.208s
# Model with rank: 1
# Mean validation score: 0.738 (std: 0.008)
# Parameters: {'shrink_threshold': 0.001, 'metric': 'euclidean'}
#
#
# Model with rank: 1
# Mean validation score: 0.738 (std: 0.008)
# Parameters: {'shrink_threshold': 0.001, 'metric': 'minkowski'}
#
#
# Validation:
# val score:   0.714
# Testing:
# test time:  0.209s
# accuracy:   0.634
# classification report:
# confusion matrix:
# [[3552 3936 1760  752]
#  [1954 5651 1939  456]
#  [ 609 1745 7193  453]
#  [ 236  430  363 8971]]
# NearestCentroid
# ________________________________________________________________________________
# Training:
# train time: 2.698s
# Model with rank: 1
# Mean validation score: 0.733 (std: 0.010)
# Parameters: {'tol': 2.477076355991714e-07, 'C': 911.1627561154896}
#
#
# Validation:
# val score:   0.698
# Testing:
# test time:  2.761s
# accuracy:   0.633
# classification report:
# confusion matrix:
# [[3749 3843 1678  730]
#  [2143 5489 1918  450]
#  [ 651 1758 7115  476]
#  [ 255  435  348 8962]]
# SVC
# ________________________________________________________________________________
# Training:
# train time: 2.814s
# Model with rank: 1
# Mean validation score: 0.738 (std: 0.014)
# Parameters: {'tol': 0.0012328467394420659, 'kernel': 'rbf', 'class_weight': 'balanced', 'C': 0.1}
#
#
# Model with rank: 1
# Mean validation score: 0.738 (std: 0.014)
# Parameters: {'tol': 2.477076355991714e-07, 'kernel': 'rbf', 'class_weight': 'balanced', 'C': 0.1}
#
#
# Validation:
# val score:   0.699
# Testing:
# test time:  2.907s
# accuracy:   0.633
# classification report:
# confusion matrix:
# [[3685 3839 1700  776]
#  [2109 5502 1918  471]
#  [ 628 1770 7131  471]
#  [ 238  413  364 8985]]
# SVC
# ________________________________________________________________________________
# Training:
# /usr/local/lib/python3.7/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# train time: 214.072s
# Model with rank: 1
# Mean validation score: 0.733 (std: 0.011)
# Parameters: {'alpha': 0.004912250531199668, 'hidden_layer_sizes': 200, 'learning_rate': 'constant'}
#
#
# Validation:
# val score:   0.694
# Testing:
# test time:  214.074s
# accuracy:   0.631
# classification report:
# confusion matrix:
# [[4133 3365 1779  723]
#  [2506 4919 2132  443]
#  [ 746 1540 7284  430]
#  [ 312  402  398 8888]]
# MLPClassifier
# ________________________________________________________________________________
# Training:
# /usr/local/lib/python3.7/site-packages/sklearn/model_selection/_search.py:266: UserWarning: The total space of parameters 16 is smaller than n_iter=20. Running 16 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# train time: 0.366s
# Model with rank: 1
# Mean validation score: 0.487 (std: 0.016)
# Parameters: {'splitter': 'best', 'max_features': None, 'criterion': 'gini'}
#
#
# Validation:
# val score:   0.466
# Testing:
# test time:  0.367s
# accuracy:   0.441
# classification report:
# confusion matrix:
# [[3117 3151 2312 1420]
#  [2482 3551 2667 1300]
#  [1464 2612 4495 1429]
#  [ 881 1479 1167 6473]]
# DecisionTreeClassifier
# ________________________________________________________________________________
# Training:
# train time: 12.523s
# Model with rank: 1
# Mean validation score: 0.655 (std: 0.011)
# Parameters: {'class_weight': 'balanced', 'criterion': 'gini', 'max_depth': 14, 'max_features': 'auto', 'n_estimators': 41}
#
#
# Validation:
# val score:   0.636
# Testing:
# test time:  12.629s
# accuracy:   0.566
# classification report:
# confusion matrix:
# [[3751 3296 1819 1134]
#  [2589 4033 2495  883]
#  [ 906 1772 6423  899]
#  [ 431  616  538 8415]]
# RandomForestClassifier
# ________________________________________________________________________________
# Training:
# train time: 0.219s
# Model with rank: 1
# Mean validation score: 0.735 (std: 0.010)
# Parameters: {'var_smoothing': 6.2802914418342724e-09}
#
#
# Model with rank: 1
# Mean validation score: 0.735 (std: 0.010)
# Parameters: {'var_smoothing': 3.764935806792471e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.735 (std: 0.010)
# Parameters: {'var_smoothing': 1.3848863713938747e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.735 (std: 0.010)
# Parameters: {'var_smoothing': 3.2745491628777316e-09}
#
#
# Model with rank: 1
# Mean validation score: 0.735 (std: 0.010)
# Parameters: {'var_smoothing': 1.6297508346206468e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.735 (std: 0.010)
# Parameters: {'var_smoothing': 1.176811952434999e-09}
#
#
# Model with rank: 1
# Mean validation score: 0.735 (std: 0.010)
# Parameters: {'var_smoothing': 4.430621457583886e-12}
#
#
# Model with rank: 1
# Mean validation score: 0.735 (std: 0.010)
# Parameters: {'var_smoothing': 2.915053062825182e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.735 (std: 0.010)
# Parameters: {'var_smoothing': 1.788649529057435e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.735 (std: 0.010)
# Parameters: {'var_smoothing': 2.5353644939701167e-12}
#
#
# Model with rank: 1
# Mean validation score: 0.735 (std: 0.010)
# Parameters: {'var_smoothing': 9.770099572992246e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.735 (std: 0.010)
# Parameters: {'var_smoothing': 4.5348785081285915e-11}
#
#
# Model with rank: 1
# Mean validation score: 0.735 (std: 0.010)
# Parameters: {'var_smoothing': 1.0476157527896662e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.735 (std: 0.010)
# Parameters: {'var_smoothing': 3.5938136638046257e-09}
#
#
# Model with rank: 1
# Mean validation score: 0.735 (std: 0.010)
# Parameters: {'var_smoothing': 1.5556761439304723e-09}
#
#
# Model with rank: 1
# Mean validation score: 0.735 (std: 0.010)
# Parameters: {'var_smoothing': 6.135907273413189e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.735 (std: 0.010)
# Parameters: {'var_smoothing': 4.229242874389499e-10}
#
#
# Model with rank: 1
# Mean validation score: 0.735 (std: 0.010)
# Parameters: {'var_smoothing': 2.0565123083486515e-09}
#
#
# Model with rank: 1
# Mean validation score: 0.735 (std: 0.010)
# Parameters: {'var_smoothing': 7.054802310718631e-12}
#
#
# Model with rank: 1
# Mean validation score: 0.735 (std: 0.010)
# Parameters: {'var_smoothing': 1.1233240329780266e-11}
#
#
# Validation:
# val score:   0.705
# Testing:
# test time:  0.226s
# accuracy:   0.632
# classification report:
# confusion matrix:
# [[3607 3893 1755  745]
#  [2018 5591 1929  462]
#  [ 613 1791 7133  463]
#  [ 250  441  346 8963]]
# GaussianNB
# ________________________________________________________________________________
# Training:
# train time: 0.348s
# Model with rank: 1
# Mean validation score: 0.732 (std: 0.013)
# Parameters: {'tol': 1.6297508346206469e-09, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.732 (std: 0.013)
# Parameters: {'tol': 6.428073117284319e-10, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.732 (std: 0.013)
# Parameters: {'tol': 1.4849682622544666e-05, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.732 (std: 0.013)
# Parameters: {'tol': 9.545484566618347e-05, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.732 (std: 0.013)
# Parameters: {'tol': 7.0548023107186455e-06, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.732 (std: 0.013)
# Parameters: {'tol': 2.0565123083486514e-07, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.732 (std: 0.013)
# Parameters: {'tol': 3.125715849688242e-05, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.732 (std: 0.013)
# Parameters: {'tol': 0.0001149756995397738, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.732 (std: 0.013)
# Parameters: {'tol': 1.6297508346206469e-09, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.732 (std: 0.013)
# Parameters: {'tol': 1.3219411484660314e-06, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.732 (std: 0.013)
# Parameters: {'tol': 2.98364724028334e-07, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.732 (std: 0.013)
# Parameters: {'tol': 3.125715849688242e-05, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.732 (std: 0.013)
# Parameters: {'tol': 0.000739072203352579, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.732 (std: 0.013)
# Parameters: {'tol': 5.336699231206302e-10, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.732 (std: 0.013)
# Parameters: {'tol': 1e-10, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.732 (std: 0.013)
# Parameters: {'tol': 9.545484566618347e-05, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.732 (std: 0.013)
# Parameters: {'tol': 1.2328467394420684e-05, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.732 (std: 0.013)
# Parameters: {'tol': 2.848035868435805e-09, 'solver': 'lsqr'}
#
#
# Model with rank: 1
# Mean validation score: 0.732 (std: 0.013)
# Parameters: {'tol': 1.8307382802953696e-08, 'solver': 'svd'}
#
#
# Model with rank: 1
# Mean validation score: 0.732 (std: 0.013)
# Parameters: {'tol': 2.104904144512022e-10, 'solver': 'svd'}
#
#
# Validation:
# val score:   0.703
# Testing:
# test time:  0.355s
# accuracy:   0.632
# classification report:
# confusion matrix:
# [[3623 3856 1746  775]
#  [1996 5519 2027  458]
#  [ 614 1725 7194  467]
#  [ 233  443  366 8958]]
# LinearDiscriminantAnalysis
# ________________________________________________________________________________
# Training:
# train time: 6.091s
# Model with rank: 1
# Mean validation score: 0.727 (std: 0.009)
# Parameters: {'tol': 1.1497569953977357e-06, 'solver': 'newton-cg', 'multi_class': 'auto', 'C': 1000}
#
#
# Validation:
# val score:   0.690
# Testing:
# test time:  6.092s
# accuracy:   0.633
# classification report:
# confusion matrix:
# [[3960 3008 1991 1041]
#  [2349 4723 2270  658]
#  [ 724 1258 7448  570]
#  [ 237  237  350 9176]]
# LogisticRegression

# %%
import datetime
# Displaying results to paste into latex
for nc in range(len(names)):
    print("\\begin{filecontents}{"+names[nc]+"-kraken.dat}\n noise 	snr accuracy") 
    for nl in range(len(noiselevel)):
        clf_descr, score, train_time, test_time, clf_rep, clf_cm=results[nl][nc]
    
        print(str(noiselevel[nl])+" "+ str(18-nl)+" "+ str(score*100))
    print("\end{filecontents}")
# Out:
# \begin{filecontents}{KNeighborsClassifier-kraken.dat}
#  noise 	snr accuracy
# 15 18 81.75
# 17 17 82.0775
# 19 16 81.8925
# 21 15 81.5025
# 26 14 78.6125
# 30 13 75.84
# 32 12 78.0025
# 33 11 73.91
# 60 10 55.6775
# \end{filecontents}
# \begin{filecontents}{NearestCentroid-kraken.dat}
#  noise 	snr accuracy
# 15 18 81.04249999999999
# 17 17 81.13749999999999
# 19 16 80.61
# 21 15 80.8275
# 26 14 79.72749999999999
# 30 13 78.365
# 32 12 78.11749999999999
# 33 11 76.99249999999999
# 60 10 63.417500000000004
# \end{filecontents}
# \begin{filecontents}{SVC-kraken.dat}
#  noise 	snr accuracy
# 15 18 84.93
# 17 17 77.33
# 19 16 80.705
# 21 15 81.525
# 26 14 79.59
# 30 13 77.07000000000001
# 32 12 78.435
# 33 11 77.0725
# 60 10 63.287499999999994
# \end{filecontents}
# \begin{filecontents}{SVC-kraken.dat}
#  noise 	snr accuracy
# 15 18 80.975
# 17 17 80.925
# 19 16 80.25750000000001
# 21 15 81.23
# 26 14 79.5775
# 30 13 78.2925
# 32 12 78.03750000000001
# 33 11 76.5275
# 60 10 63.2575
# \end{filecontents}
# \begin{filecontents}{MLPClassifier-kraken.dat}
#  noise 	snr accuracy
# 15 18 79.835
# 17 17 80.8675
# 19 16 81.74249999999999
# 21 15 79.86
# 26 14 79.3625
# 30 13 78.2825
# 32 12 77.66
# 33 11 76.2
# 60 10 63.06
# \end{filecontents}
# \begin{filecontents}{DecisionTreeClassifier-kraken.dat}
#  noise 	snr accuracy
# 15 18 78.67
# 17 17 75.6375
# 19 16 73.705
# 21 15 73.5575
# 26 14 69.075
# 30 13 64.2525
# 32 12 65.185
# 33 11 61.58749999999999
# 60 10 44.09
# \end{filecontents}
# \begin{filecontents}{RandomForestClassifier-kraken.dat}
#  noise 	snr accuracy
# 15 18 82.0625
# 17 17 81.425
# 19 16 80.14250000000001
# 21 15 79.5225
# 26 14 77.185
# 30 13 75.1075
# 32 12 76.1525
# 33 11 73.5675
# 60 10 56.555
# \end{filecontents}
# \begin{filecontents}{GaussianNB-kraken.dat}
#  noise 	snr accuracy
# 15 18 81.1925
# 17 17 81.27499999999999
# 19 16 80.21000000000001
# 21 15 80.6875
# 26 14 79.7175
# 30 13 78.225
# 32 12 77.8275
# 33 11 76.935
# 60 10 63.235
# \end{filecontents}
# \begin{filecontents}{LinearDiscriminantAnalysis-kraken.dat}
#  noise 	snr accuracy
# 15 18 81.13749999999999
# 17 17 81.04249999999999
# 19 16 80.49
# 21 15 81.0025
# 26 14 79.565
# 30 13 78.405
# 32 12 78.06
# 33 11 76.715
# 60 10 63.235
# \end{filecontents}
# \begin{filecontents}{LogisticRegression-kraken.dat}
#  noise 	snr accuracy
# 15 18 87.9
# 17 17 84.165
# 19 16 85.15
# 21 15 84.7
# 26 14 82.075
# 30 13 79.43
# 32 12 78.4375
# 33 11 77.425
# 60 10 63.2675
# \end{filecontents}

# %%
# Displaying results in a pandas dataframe
#Code adapted from https://www.kaggle.com/grfiv4/displaying-the-results-of-a-grid-search
import pandas as pd
def score_summary(grid_searches, sort_by='mean_test_score'):
        frames = []
        for name, grid_search in grid_searches.items():
            frame = pd.DataFrame(grid_search.cv_results_)
            frame = frame.filter(regex='^(?!.*param_).*$')
            frame['estimator'] = len(frame)*[name]
            frames.append(frame)
        df = pd.concat(frames)
        
        df = df.sort_values([sort_by], ascending=False)
        df = df.reset_index()
        df = df.drop(['rank_test_score', 'index'], 1)
        
        columns = df.columns.tolist()
        columns.remove('estimator')
        columns = ['estimator']+columns
        df = df[columns]
        return df

# %%
df=score_summary(grid_searches[0])
print(noiselevel[0])
df
